# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

# Define a function to get the urls for each power forward's personal page
def get_pf_urls(season_url):
    response = requests.get(season_url)
    soup = BeautifulSoup(response.content, 'lxml')
    players_table = soup.find('table', {'id': 'advanced_stats'})
    players = []
    for row in players_table.tbody.find_all('tr'):
        pos_cell = row.find('td', {'data-stat': 'pos'})
        if pos_cell is not None:  # Check if the 'pos' cell exists
            position = pos_cell.text
            if 'PF' in position:
                player_link = row.find('td', {'data-stat': 'player'}).a['href']
                player_name = row.find('td', {'data-stat': 'player'}).text
                players.append((player_name, 'https://www.basketball-reference.com' + player_link))
    return players

season_2014_url = "https://www.basketball-reference.com/leagues/NBA_2014_advanced.html"
season_2024_url = "https://www.basketball-reference.com/leagues/NBA_2024_advanced.html"
pf_players_2014 = get_pf_urls(season_2014_url)
pf_players_2024 = get_pf_urls(season_2024_url)

# %%
pf_players_2014
# Out:
# [('Jeff Adrien',
#   'https://www.basketball-reference.com/players/a/adrieje01.html'),
#  ('Jeff Adrien',
#   'https://www.basketball-reference.com/players/a/adrieje01.html'),
#  ('Jeff Adrien',
#   'https://www.basketball-reference.com/players/a/adrieje01.html'),
#  ('LaMarcus Aldridge',
#   'https://www.basketball-reference.com/players/a/aldrila01.html'),
#  ('Lavoy Allen',
#   'https://www.basketball-reference.com/players/a/allenla01.html'),
#  ('Lavoy Allen',
#   'https://www.basketball-reference.com/players/a/allenla01.html'),
#  ('Lavoy Allen',
#   'https://www.basketball-reference.com/players/a/allenla01.html'),
#  ('Lou Amundson',
#   'https://www.basketball-reference.com/players/a/amundlo01.html'),
#  ('Lou Amundson',
#   'https://www.basketball-reference.com/players/a/amundlo01.html'),
#  ('Lou Amundson',
#   'https://www.basketball-reference.com/players/a/amundlo01.html'),
#  ('Ryan Anderson',
#   'https://www.basketball-reference.com/players/a/anderry01.html'),
#  ('Carmelo Anthony',
#   'https://www.basketball-reference.com/players/a/anthoca01.html'),
#  ('Jeff Ayres',
#   'https://www.basketball-reference.com/players/p/pendeje02.html'),
#  ('Luke Babbitt',
#   'https://www.basketball-reference.com/players/b/babbilu01.html'),
#  ('Brandon Bass',
#   'https://www.basketball-reference.com/players/b/bassbr01.html'),
#  ('Anthony Bennett',
#   'https://www.basketball-reference.com/players/b/bennean01.html'),
#  ('DeJuan Blair',
#   'https://www.basketball-reference.com/players/b/blairde01.html'),
#  ('Andray Blatche',
#   'https://www.basketball-reference.com/players/b/blatcan01.html'),
#  ('Matt Bonner',
#   'https://www.basketball-reference.com/players/b/bonnema01.html'),
#  ('Trevor Booker',
#   'https://www.basketball-reference.com/players/b/booketr01.html'),
#  ('Carlos Boozer',
#   'https://www.basketball-reference.com/players/b/boozeca01.html'),
#  ('Omri Casspi',
#   'https://www.basketball-reference.com/players/c/casspom01.html'),
#  ('Earl Clark',
#   'https://www.basketball-reference.com/players/c/clarkea01.html'),
#  ('Earl Clark',
#   'https://www.basketball-reference.com/players/c/clarkea01.html'),
#  ('Earl Clark',
#   'https://www.basketball-reference.com/players/c/clarkea01.html'),
#  ('Nick Collison',
#   'https://www.basketball-reference.com/players/c/collini01.html'),
#  ('Dante Cunningham',
#   'https://www.basketball-reference.com/players/c/cunnida01.html'),
#  ('Brandon Davies',
#   'https://www.basketball-reference.com/players/d/daviebr01.html'),
#  ('Anthony Davis',
#   'https://www.basketball-reference.com/players/d/davisan02.html'),
#  ('Ed Davis', 'https://www.basketball-reference.com/players/d/davised01.html'),
#  ('Glen Davis',
#   'https://www.basketball-reference.com/players/d/davisgl01.html'),
#  ('Glen Davis',
#   'https://www.basketball-reference.com/players/d/davisgl01.html'),
#  ('Glen Davis',
#   'https://www.basketball-reference.com/players/d/davisgl01.html'),
#  ('Boris Diaw',
#   'https://www.basketball-reference.com/players/d/diawbo01.html'),
#  ('Reggie Evans',
#   'https://www.basketball-reference.com/players/e/evansre01.html'),
#  ('Reggie Evans',
#   'https://www.basketball-reference.com/players/e/evansre01.html'),
#  ('Reggie Evans',
#   'https://www.basketball-reference.com/players/e/evansre01.html'),
#  ('Kenneth Faried',
#   'https://www.basketball-reference.com/players/f/farieke01.html'),
#  ('Derrick Favors',
#   'https://www.basketball-reference.com/players/f/favorde01.html'),
#  ('Channing Frye',
#   'https://www.basketball-reference.com/players/f/fryech01.html'),
#  ('Taj Gibson',
#   'https://www.basketball-reference.com/players/g/gibsota01.html'),
#  ('Blake Griffin',
#   'https://www.basketball-reference.com/players/g/griffbl01.html'),
#  ('Tyler Hansbrough',
#   'https://www.basketball-reference.com/players/h/hansbty01.html'),
#  ('Al Harrington',
#   'https://www.basketball-reference.com/players/h/harrial01.html'),
#  ('Mike Harris',
#   'https://www.basketball-reference.com/players/h/harrimi01.html'),
#  ('Tobias Harris',
#   'https://www.basketball-reference.com/players/h/harrito02.html'),
#  ('Udonis Haslem',
#   'https://www.basketball-reference.com/players/h/hasleud01.html'),
#  ('John Henson',
#   'https://www.basketball-reference.com/players/h/hensojo01.html'),
#  ('J.J. Hickson',
#   'https://www.basketball-reference.com/players/h/hicksjj01.html'),
#  ('Nenê', 'https://www.basketball-reference.com/players/h/hilarne01.html'),
#  ('Jordan Hill',
#   'https://www.basketball-reference.com/players/h/hilljo01.html'),
#  ('Ryan Hollins',
#   'https://www.basketball-reference.com/players/h/holliry01.html'),
#  ('Kris Humphries',
#   'https://www.basketball-reference.com/players/h/humphkr01.html'),
#  ('Serge Ibaka',
#   'https://www.basketball-reference.com/players/i/ibakase01.html'),
#  ('Ersan İlyasova',
#   'https://www.basketball-reference.com/players/i/ilyaser01.html'),
#  ('LeBron James',
#   'https://www.basketball-reference.com/players/j/jamesle01.html'),
#  ('Antawn Jamison',
#   'https://www.basketball-reference.com/players/j/jamisan01.html'),
#  ('Jonas Jerebko',
#   'https://www.basketball-reference.com/players/j/jerebjo01.html'),
#  ('Amir Johnson',
#   'https://www.basketball-reference.com/players/j/johnsam01.html'),
#  ('Perry Jones',
#   'https://www.basketball-reference.com/players/j/jonespe01.html'),
#  ('Solomon Jones',
#   'https://www.basketball-reference.com/players/j/jonesso01.html'),
#  ('Terrence Jones',
#   'https://www.basketball-reference.com/players/j/joneste01.html'),
#  ('Ryan Kelly',
#   'https://www.basketball-reference.com/players/k/kellyry01.html'),
#  ('Andrei Kirilenko',
#   'https://www.basketball-reference.com/players/k/kirilan01.html'),
#  ('Carl Landry',
#   'https://www.basketball-reference.com/players/l/landrca01.html'),
#  ('David Lee', 'https://www.basketball-reference.com/players/l/leeda02.html'),
#  ('Jon Leuer',
#   'https://www.basketball-reference.com/players/l/leuerjo01.html'),
#  ('Kevin Love',
#   'https://www.basketball-reference.com/players/l/loveke01.html'),
#  ('Kenyon Martin',
#   'https://www.basketball-reference.com/players/m/martike01.html'),
#  ('Jason Maxiell',
#   'https://www.basketball-reference.com/players/m/maxieja01.html'),
#  ('Luc Mbah a Moute',
#   'https://www.basketball-reference.com/players/m/mbahalu01.html'),
#  ('Luc Mbah a Moute',
#   'https://www.basketball-reference.com/players/m/mbahalu01.html'),
#  ('Josh McRoberts',
#   'https://www.basketball-reference.com/players/m/mcrobjo01.html'),
#  ('Quincy Miller',
#   'https://www.basketball-reference.com/players/m/millequ01.html'),
#  ('Paul Millsap',
#   'https://www.basketball-reference.com/players/m/millspa01.html'),
#  ('Tony Mitchell',
#   'https://www.basketball-reference.com/players/m/mitchto02.html'),
#  ('Greg Monroe',
#   'https://www.basketball-reference.com/players/m/monrogr01.html'),
#  ('Markieff Morris',
#   'https://www.basketball-reference.com/players/m/morrima02.html'),
#  ('Donatas Motiejūnas',
#   'https://www.basketball-reference.com/players/m/motiedo01.html'),
#  ('Arnett Moultrie',
#   'https://www.basketball-reference.com/players/m/moultar01.html'),
#  ('Mike Muscala',
#   'https://www.basketball-reference.com/players/m/muscami01.html'),
#  ('Andrew Nicholson',
#   'https://www.basketball-reference.com/players/n/nichoan01.html'),
#  ('Steve Novak',
#   'https://www.basketball-reference.com/players/n/novakst01.html'),
#  ('Dirk Nowitzki*',
#   'https://www.basketball-reference.com/players/n/nowitdi01.html'),
#  ("Jermaine O'Neal",
#   'https://www.basketball-reference.com/players/o/onealje01.html'),
#  ('Arinze Onuaku',
#   'https://www.basketball-reference.com/players/o/onuakar01.html'),
#  ('Arinze Onuaku',
#   'https://www.basketball-reference.com/players/o/onuakar01.html'),
#  ('Arinze Onuaku',
#   'https://www.basketball-reference.com/players/o/onuakar01.html'),
#  ('Patrick Patterson',
#   'https://www.basketball-reference.com/players/p/pattepa01.html'),
#  ('Patrick Patterson',
#   'https://www.basketball-reference.com/players/p/pattepa01.html'),
#  ('Patrick Patterson',
#   'https://www.basketball-reference.com/players/p/pattepa01.html'),
#  ('Josh Powell',
#   'https://www.basketball-reference.com/players/p/poweljo01.html'),
#  ('Anthony Randolph',
#   'https://www.basketball-reference.com/players/r/randoan01.html'),
#  ('Shavlik Randolph',
#   'https://www.basketball-reference.com/players/r/randosh01.html'),
#  ('Zach Randolph',
#   'https://www.basketball-reference.com/players/r/randoza01.html'),
#  ('Thomas Robinson',
#   'https://www.basketball-reference.com/players/r/robinth01.html'),
#  ('Luis Scola',
#   'https://www.basketball-reference.com/players/s/scolalu01.html'),
#  ('Mike Scott',
#   'https://www.basketball-reference.com/players/s/scottmi01.html'),
#  ('Jason Smith',
#   'https://www.basketball-reference.com/players/s/smithja02.html'),
#  ('Jared Sullinger',
#   'https://www.basketball-reference.com/players/s/sullija01.html'),
#  ('Malcolm Thomas',
#   'https://www.basketball-reference.com/players/t/thomama01.html'),
#  ('Malcolm Thomas',
#   'https://www.basketball-reference.com/players/t/thomama01.html'),
#  ('Malcolm Thomas',
#   'https://www.basketball-reference.com/players/t/thomama01.html'),
#  ('Jason Thompson',
#   'https://www.basketball-reference.com/players/t/thompja02.html'),
#  ('Tristan Thompson',
#   'https://www.basketball-reference.com/players/t/thomptr01.html'),
#  ('Anthony Tolliver',
#   'https://www.basketball-reference.com/players/t/tollian01.html'),
#  ('Ekpe Udoh', 'https://www.basketball-reference.com/players/u/udohek01.html'),
#  ('Jarvis Varnado',
#   'https://www.basketball-reference.com/players/v/varnaja01.html'),
#  ('Jarvis Varnado',
#   'https://www.basketball-reference.com/players/v/varnaja01.html'),
#  ('Jarvis Varnado',
#   'https://www.basketball-reference.com/players/v/varnaja01.html'),
#  ('Jan Veselý',
#   'https://www.basketball-reference.com/players/v/veselja01.html'),
#  ('Jan Veselý',
#   'https://www.basketball-reference.com/players/v/veselja01.html'),
#  ('Jan Veselý',
#   'https://www.basketball-reference.com/players/v/veselja01.html'),
#  ('Charlie Villanueva',
#   'https://www.basketball-reference.com/players/v/villach01.html'),
#  ('David West',
#   'https://www.basketball-reference.com/players/w/westda01.html'),
#  ('D.J. White',
#   'https://www.basketball-reference.com/players/w/whitedj01.html'),
#  ('Royce White',
#   'https://www.basketball-reference.com/players/w/whitero03.html'),
#  ('Derrick Williams',
#   'https://www.basketball-reference.com/players/w/willide02.html'),
#  ('Derrick Williams',
#   'https://www.basketball-reference.com/players/w/willide02.html'),
#  ('Marvin Williams',
#   'https://www.basketball-reference.com/players/w/willima02.html'),
#  ('Shawne Williams',
#   'https://www.basketball-reference.com/players/w/willish03.html'),
#  ('Thaddeus Young',
#   'https://www.basketball-reference.com/players/y/youngth01.html')]

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time

def get_shooting_data(player_url, season, player_name):
    # Initialize Selenium WebDriver
    driver = webdriver.Chrome()  # Make sure you have the ChromeDriver installed and in PATH
    driver.get(player_url)
    
    # Wait for the page to fully load (you might need to adjust this delay)
    time.sleep(10)
    
    # Get page source and parse it with BeautifulSoup
    soup = BeautifulSoup(driver.page_source, 'lxml')
    
    # Close the driver after page load
    driver.quit()
    
    # List of possible table IDs
    table_ids = ['shooting_sh', 'div_shooting', 'shooting']
    
    shooting_table = None
    for table_id in table_ids:
        shooting_table = soup.find('table', {'id': table_id})
        if shooting_table is not None:
            break
    
    if shooting_table is None:
        print(f"No shooting data found for {player_url}")
        return []
    
    # Find the headers
    headers = [th.text.strip() for th in shooting_table.find('thead').find_all('th')]
    headers = headers[14:39]
    for header in headers:
        if header == '':
            headers.remove('')
    headers[8] = '% of FGA by Distance: 2P'
    headers[9] = '% of FGA by Distance: 0-3ft'
    headers[10] = '% of FGA by Distance: 3-10ft'
    headers[11] = '% of FGA by Distance: 10-16ft'
    headers[12] = '% of FGA by Distance: 16-3P'
    headers[13] = '% of FGA by Distance: 3P'
    headers[14] = 'FG% by Distance: 2P'
    headers[15] = 'FG% by Distance: 0-3ft'
    headers[16] = 'FG% by Distance: 3-10ft'
    headers[17] = 'FG% by Distance: 10-16ft'
    headers[18] = 'FG% by Distance: 16-3P'
    headers[19] = 'FG% by Distance: 3P'
    headers[20] = "% of FG Ast'd: 2P"
    headers[21] = "% of FG Ast'd: 3P"
    headers.append("Player")
    
    data_rows = shooting_table.tbody.find_all('tr')
    
    season_data = []

    # Iterate over rows to find data for the specific season and 'TOT' if available
    for row in data_rows:
        season_cell = row.find('th', {'data-stat': 'season'})
        team_id_cell = row.find('td', {'data-stat': 'team_id'})
        
        if season_cell.text.strip() == season:
            data = [td.text.strip() for td in row.find_all('td')][:25]
            data.pop(8)
            data.pop(14)
            data.pop(20)
            data.append(player_name)
            df = pd.DataFrame([data], columns=headers)
            df.set_index("Player", inplace=True)
            return df
        
    return pd.DataFrame()

shooting_data_dfs = {}
for pf in pf_players_2014:
    if pf[0] not in shooting_data_dfs.keys():
        shooting_data_dfs[pf[0]] = get_shooting_data(pf[1], '2013-14', pf[0])

shooting_data = pd.concat(shooting_data_dfs.values())
shooting_data
# Out:
#                   Age   Tm   Lg    Pos   G    MP   FG% Dist.  \
# Player
# Jeff Adrien        27  TOT  NBA     PF  53   961  .520   5.5
# LaMarcus Aldridge  28  POR  NBA     PF  69  2498  .458  12.5
# Lavoy Allen        24  TOT  NBA     PF  65  1072  .447   9.7
# Lou Amundson       31  TOT  NBA     PF  19   185  .500   4.1
# Ryan Anderson      25  NOP  NBA     PF  22   795  .438  16.8
# ...                ..  ...  ...    ...  ..   ...   ...   ...
# Royce White        22  SAC  NBA     PF   3     9  .000  14.1
# Derrick Williams   22  TOT  NBA  PF,SF  78  1820  .427  10.8
# Marvin Williams    27  UTA  NBA     PF  66  1674  .439  16.6
# Shawne Williams    27  LAL  NBA     PF  36   751  .380  19.4
# Thaddeus Young     25  PHI  NBA     PF  79  2718  .454  10.3
#
#                   % of FGA by Distance: 2P % of FGA by Distance: 0-3ft  ...  \
# Player                                                                  ...
# Jeff Adrien                          1.000                        .560  ...
# LaMarcus Aldridge                     .989                        .186  ...
# Lavoy Allen                           .957                        .290  ...
# Lou Amundson                         1.000                        .625  ...
# Ryan Anderson                         .537                        .198  ...
# ...                                    ...                         ...  ...
# Royce White                          1.000                        .000  ...
# Derrick Williams                      .795                        .334  ...
# Marvin Williams                       .555                        .194  ...
# Shawne Williams                       .328                        .151  ...
# Thaddeus Young                        .772                        .377  ...
#
#                   % of FGA by Distance: 16-3P % of FGA by Distance: 3P  \
# Player
# Jeff Adrien                              .120                     .000
# LaMarcus Aldridge                        .415                     .011
# Lavoy Allen                              .257                     .043
# Lou Amundson                             .031                     .000
# Ryan Anderson                            .155                     .463
# ...                                       ...                      ...
# Royce White                              .000                     .000
# Derrick Williams                         .135                     .205
# Marvin Williams                          .179                     .445
# Shawne Williams                          .120                     .672
# Thaddeus Young                           .112                     .228
#
#                   FG% by Distance: 2P FG% by Distance: 0-3ft  \
# Player
# Jeff Adrien                      .520                   .617
# LaMarcus Aldridge                .461                   .675
# Lavoy Allen                      .460                   .563
# Lou Amundson                     .500                   .650
# Ryan Anderson                    .463                   .529
# ...                               ...                    ...
# Royce White                      .000
# Derrick Williams                 .470                   .658
# Marvin Williams                  .503                   .725
# Shawne Williams                  .492                   .483
# Thaddeus Young                   .496                   .645
#
#                   FG% by Distance: 3-10ft FG% by Distance: 10-16ft  \
# Player
# Jeff Adrien                          .426                     .333
# LaMarcus Aldridge                    .364                     .388
# Lavoy Allen                          .531                     .286
# Lou Amundson                         .333                     .000
# Ryan Anderson                        .333                     .344
# ...                                   ...                      ...
# Royce White                                                   .000
# Derrick Williams                     .333                     .354
# Marvin Williams                      .406                     .344
# Shawne Williams                      .250                     .667
# Thaddeus Young                       .374                     .338
#
#                   FG% by Distance: 16-3P FG% by Distance: 3P  \
# Player
# Jeff Adrien                         .394
# LaMarcus Aldridge                   .442                .200
# Lavoy Allen                         .364                .154
# Lou Amundson                        .000
# Ryan Anderson                       .527                .409
# ...                                  ...                 ...
# Royce White
# Derrick Williams                    .323                .263
# Marvin Williams                     .383                .359
# Shawne Williams                     .565                .326
# Thaddeus Young                      .326                .308
#
#                   % of FG Ast'd: 2P % of FG Ast'd: 3P
# Player
# Jeff Adrien                    .643
# LaMarcus Aldridge              .599              .667
# Lavoy Allen                    .697             1.000
# Lou Amundson                   .750
# Ryan Anderson                  .420              .985
# ...                             ...               ...
# Royce White
# Derrick Williams               .600              .846
# Marvin Williams                .605              .988
# Shawne Williams                .742              .952
# Thaddeus Young                 .559              .922
#
# [98 rows x 22 columns]
