# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re

# Define a function to get the urls for each power forward's personal page
def get_pf_urls(season_url):
    response = requests.get(season_url)
    soup = BeautifulSoup(response.content, 'lxml')
    players_table = soup.find('table', {'id': 'advanced_stats'})
    players = []
    for row in players_table.tbody.find_all('tr'):
        pos_cell = row.find('td', {'data-stat': 'pos'})
        if pos_cell is not None:  # Check if the 'pos' cell exists
            position = pos_cell.text
            if 'PF' in position:
                player_link = row.find('td', {'data-stat': 'player'}).a['href']
                player_name = row.find('td', {'data-stat': 'player'}).text
                players.append((player_name, 'https://www.basketball-reference.com' + player_link))
    return players

season_2014_url = "https://www.basketball-reference.com/leagues/NBA_2014_advanced.html"
season_2024_url = "https://www.basketball-reference.com/leagues/NBA_2024_advanced.html"
pf_players_2014 = get_pf_urls(season_2014_url)
pf_players_2024 = get_pf_urls(season_2024_url)

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time
from selenium.webdriver.chrome.options import Options

def get_shooting_data(player_url, season, player_name):
    # Initialize Selenium WebDriver
    options = Options()
    options.headless = True
    driver = webdriver.Chrome(options=options)  # Make sure you have the ChromeDriver installed and in PATH
    driver.get(player_url)
    
    # Wait for the page to fully load (you might need to adjust this delay)
    time.sleep(10)
    
    # Get page source and parse it with BeautifulSoup
    soup = BeautifulSoup(driver.page_source, 'lxml')
    
    # Close the driver after page load
    driver.quit()
    
    # List of possible table IDs
    table_ids = ['shooting_sh', 'div_shooting', 'shooting']
    
    shooting_table = None
    for table_id in table_ids:
        shooting_table = soup.find('table', {'id': table_id})
        if shooting_table is not None:
            break
    
    if shooting_table is None:
        print(f"No shooting data found for {player_url}")
        return []
    
    # Find the headers
    headers = [th.text.strip() for th in shooting_table.find('thead').find_all('th')]
    headers = headers[14:39]
    for header in headers:
        if header == '':
            headers.remove('')
    headers[8] = '% of FGA by Distance: 2P'
    headers[9] = '% of FGA by Distance: 0-3ft'
    headers[10] = '% of FGA by Distance: 3-10ft'
    headers[11] = '% of FGA by Distance: 10-16ft'
    headers[12] = '% of FGA by Distance: 16-3P'
    headers[13] = '% of FGA by Distance: 3P'
    headers[14] = 'FG% by Distance: 2P'
    headers[15] = 'FG% by Distance: 0-3ft'
    headers[16] = 'FG% by Distance: 3-10ft'
    headers[17] = 'FG% by Distance: 10-16ft'
    headers[18] = 'FG% by Distance: 16-3P'
    headers[19] = 'FG% by Distance: 3P'
    headers[20] = "% of FG Ast'd: 2P"
    headers[21] = "% of FG Ast'd: 3P"
    headers.append("Player")
    
    data_rows = shooting_table.tbody.find_all('tr')
    
    season_data = []

    # Iterate over rows to find data for the specific season and 'TOT' if available
    for row in data_rows:
        season_cell = row.find('th', {'data-stat': 'season'})
        team_id_cell = row.find('td', {'data-stat': 'team_id'})
        
        if season_cell.text.strip() == season:
            data = [td.text.strip() for td in row.find_all('td')][:25]
            data.pop(8)
            data.pop(14)
            data.pop(20)
            data.append(player_name)
            df = pd.DataFrame([data], columns=headers)
            df.set_index("Player", inplace=True)
            return df
        
    return pd.DataFrame()

# %%
# Get the shooting dataframe for the 2013-14 power forwards
shooting_data_dfs_2014 = {}
for pf in pf_players_2014:
    if pf[0] not in shooting_data_dfs_2014.keys():
        shooting_data_dfs_2014[pf[0]] = get_shooting_data(pf[1], '2013-14', pf[0])

shooting_data_2014 = pd.concat(shooting_data_dfs_2014.values())
shooting_data_2014

# %%
pf_players_2024
# Out:
# [('Precious Achiuwa',
#   'https://www.basketball-reference.com/players/a/achiupr01.html'),
#  ('Precious Achiuwa',
#   'https://www.basketball-reference.com/players/a/achiupr01.html'),
#  ('Santi Aldama',
#   'https://www.basketball-reference.com/players/a/aldamsa01.html'),
#  ('Kyle Anderson',
#   'https://www.basketball-reference.com/players/a/anderky01.html'),
#  ('Giannis Antetokounmpo',
#   'https://www.basketball-reference.com/players/a/antetgi01.html'),
#  ('Thanasis Antetokounmpo',
#   'https://www.basketball-reference.com/players/a/antetth01.html'),
#  ('Paolo Banchero',
#   'https://www.basketball-reference.com/players/b/banchpa01.html'),
#  ('Dominick Barlow',
#   'https://www.basketball-reference.com/players/b/barlodo01.html'),
#  ('Harrison Barnes',
#   'https://www.basketball-reference.com/players/b/barneha02.html'),
#  ('Nicolas Batum',
#   'https://www.basketball-reference.com/players/b/batumni01.html'),
#  ('Nicolas Batum',
#   'https://www.basketball-reference.com/players/b/batumni01.html'),
#  ('Nicolas Batum',
#   'https://www.basketball-reference.com/players/b/batumni01.html'),
#  ('Darius Bazley',
#   'https://www.basketball-reference.com/players/b/bazleda01.html'),
#  ('Darius Bazley',
#   'https://www.basketball-reference.com/players/b/bazleda01.html'),
#  ('Darius Bazley',
#   'https://www.basketball-reference.com/players/b/bazleda01.html'),
#  ('Dāvis Bertāns',
#   'https://www.basketball-reference.com/players/b/bertada01.html'),
#  ('Dāvis Bertāns',
#   'https://www.basketball-reference.com/players/b/bertada01.html'),
#  ('Dāvis Bertāns',
#   'https://www.basketball-reference.com/players/b/bertada01.html'),
#  ('Bojan Bogdanović',
#   'https://www.basketball-reference.com/players/b/bogdabo02.html'),
#  ('Bojan Bogdanović',
#   'https://www.basketball-reference.com/players/b/bogdabo02.html'),
#  ('Bol Bol', 'https://www.basketball-reference.com/players/b/bolbo01.html'),
#  ('Chris Boucher',
#   'https://www.basketball-reference.com/players/b/bouchch01.html'),
#  ('Greg Brown III',
#   'https://www.basketball-reference.com/players/b/browngr01.html'),
#  ('Kobe Brown',
#   'https://www.basketball-reference.com/players/b/brownko01.html'),
#  ('Jimmy Butler',
#   'https://www.basketball-reference.com/players/b/butleji01.html'),
#  ('Jamal Cain',
#   'https://www.basketball-reference.com/players/c/cainja01.html'),
#  ('Toumani Camara',
#   'https://www.basketball-reference.com/players/c/camarto01.html'),
#  ('Brandon Clarke',
#   'https://www.basketball-reference.com/players/c/clarkbr01.html'),
#  ('Noah Clowney',
#   'https://www.basketball-reference.com/players/c/clownno01.html'),
#  ('John Collins',
#   'https://www.basketball-reference.com/players/c/collijo01.html'),
#  ('Robert Covington',
#   'https://www.basketball-reference.com/players/c/covinro01.html'),
#  ('Robert Covington',
#   'https://www.basketball-reference.com/players/c/covinro01.html'),
#  ('Jae Crowder',
#   'https://www.basketball-reference.com/players/c/crowdja01.html'),
#  ('Mamadi Diakite',
#   'https://www.basketball-reference.com/players/d/diakima01.html'),
#  ('Mamadi Diakite',
#   'https://www.basketball-reference.com/players/d/diakima01.html'),
#  ('Mamadi Diakite',
#   'https://www.basketball-reference.com/players/d/diakima01.html'),
#  ('Ousmane Dieng',
#   'https://www.basketball-reference.com/players/d/diengou01.html'),
#  ('Kevin Durant',
#   'https://www.basketball-reference.com/players/d/duranke01.html'),
#  ('Tari Eason',
#   'https://www.basketball-reference.com/players/e/easonta01.html'),
#  ('Dorian Finney-Smith',
#   'https://www.basketball-reference.com/players/f/finnedo01.html'),
#  ('Wenyen Gabriel',
#   'https://www.basketball-reference.com/players/g/gabriwe01.html'),
#  ('Daniel Gafford',
#   'https://www.basketball-reference.com/players/g/gaffoda01.html'),
#  ('Daniel Gafford',
#   'https://www.basketball-reference.com/players/g/gaffoda01.html'),
#  ('Danilo Gallinari',
#   'https://www.basketball-reference.com/players/g/gallida01.html'),
#  ('Danilo Gallinari',
#   'https://www.basketball-reference.com/players/g/gallida01.html'),
#  ('Usman Garuba',
#   'https://www.basketball-reference.com/players/g/garubus01.html'),
#  ('Paul George',
#   'https://www.basketball-reference.com/players/g/georgpa01.html'),
#  ('Taj Gibson',
#   'https://www.basketball-reference.com/players/g/gibsota01.html'),
#  ('Taj Gibson',
#   'https://www.basketball-reference.com/players/g/gibsota01.html'),
#  ('Taj Gibson',
#   'https://www.basketball-reference.com/players/g/gibsota01.html'),
#  ('Anthony Gill',
#   'https://www.basketball-reference.com/players/g/gillan01.html'),
#  ('Aaron Gordon',
#   'https://www.basketball-reference.com/players/g/gordoaa01.html'),
#  ('Jerami Grant',
#   'https://www.basketball-reference.com/players/g/grantje01.html'),
#  ('RaiQuan Gray',
#   'https://www.basketball-reference.com/players/g/grayra01.html'),
#  ('Draymond Green',
#   'https://www.basketball-reference.com/players/g/greendr01.html'),
#  ('Jeff Green',
#   'https://www.basketball-reference.com/players/g/greenje02.html'),
#  ('Mouhamadou Gueye',
#   'https://www.basketball-reference.com/players/g/gueyemo01.html'),
#  ('Mouhamed Gueye',
#   'https://www.basketball-reference.com/players/g/gueyemo02.html'),
#  ('Rui Hachimura',
#   'https://www.basketball-reference.com/players/h/hachiru01.html'),
#  ('Ron Harper Jr.',
#   'https://www.basketball-reference.com/players/h/harpero02.html'),
#  ('Tobias Harris',
#   'https://www.basketball-reference.com/players/h/harrito02.html'),
#  ('Taylor Hendricks',
#   'https://www.basketball-reference.com/players/h/hendrita01.html'),
#  ('Haywood Highsmith',
#   'https://www.basketball-reference.com/players/h/highsha01.html'),
#  ('Richaun Holmes',
#   'https://www.basketball-reference.com/players/h/holmeri01.html'),
#  ('Richaun Holmes',
#   'https://www.basketball-reference.com/players/h/holmeri01.html'),
#  ('Matthew Hurt',
#   'https://www.basketball-reference.com/players/h/hurtma01.html'),
#  ('Jonathan Isaac',
#   'https://www.basketball-reference.com/players/i/isaacjo01.html'),
#  ('GG Jackson II',
#   'https://www.basketball-reference.com/players/j/jacksgg01.html'),
#  ('Trayce Jackson-Davis',
#   'https://www.basketball-reference.com/players/j/jackstr02.html'),
#  ('LeBron James',
#   'https://www.basketball-reference.com/players/j/jamesle01.html'),
#  ('Cameron Johnson',
#   'https://www.basketball-reference.com/players/j/johnsca02.html'),
#  ('James Johnson',
#   'https://www.basketball-reference.com/players/j/johnsja01.html'),
#  ('Nikola Jović',
#   'https://www.basketball-reference.com/players/j/jovicni01.html'),
#  ('Jonathan Kuminga',
#   'https://www.basketball-reference.com/players/k/kuminjo01.html'),
#  ('Kyle Kuzma',
#   'https://www.basketball-reference.com/players/k/kuzmaky01.html'),
#  ('Jake LaRavia',
#   'https://www.basketball-reference.com/players/l/laravja01.html'),
#  ('E.J. Liddell',
#   'https://www.basketball-reference.com/players/l/liddeej01.html'),
#  ('Isaiah Livers',
#   'https://www.basketball-reference.com/players/l/liveris01.html'),
#  ('Kenneth Lofton Jr.',
#   'https://www.basketball-reference.com/players/l/loftoke01.html'),
#  ('Kenneth Lofton Jr.',
#   'https://www.basketball-reference.com/players/l/loftoke01.html'),
#  ('Kenneth Lofton Jr.',
#   'https://www.basketball-reference.com/players/l/loftoke01.html'),
#  ('Kenneth Lofton Jr.',
#   'https://www.basketball-reference.com/players/l/loftoke01.html'),
#  ('Kevin Love',
#   'https://www.basketball-reference.com/players/l/loveke01.html'),
#  ('Trey Lyles',
#   'https://www.basketball-reference.com/players/l/lylestr01.html'),
#  ('Lauri Markkanen',
#   'https://www.basketball-reference.com/players/m/markkla01.html'),
#  ('Evan Mobley',
#   'https://www.basketball-reference.com/players/m/mobleev01.html'),
#  ('Isaiah Mobley',
#   'https://www.basketball-reference.com/players/m/mobleis01.html'),
#  ('Marcus Morris',
#   'https://www.basketball-reference.com/players/m/morrima03.html'),
#  ('Marcus Morris',
#   'https://www.basketball-reference.com/players/m/morrima03.html'),
#  ('Marcus Morris',
#   'https://www.basketball-reference.com/players/m/morrima03.html'),
#  ('Markieff Morris',
#   'https://www.basketball-reference.com/players/m/morrima02.html'),
#  ('Pete Nance',
#   'https://www.basketball-reference.com/players/n/nancepe01.html'),
#  ('Georges Niang',
#   'https://www.basketball-reference.com/players/n/niangge01.html'),
#  ('Zeke Nnaji',
#   'https://www.basketball-reference.com/players/n/nnajize01.html'),
#  ('Drew Peterson',
#   'https://www.basketball-reference.com/players/p/peterdr01.html'),
#  ('Aleksej Pokusevski',
#   'https://www.basketball-reference.com/players/p/pokusal01.html'),
#  ('Aleksej Pokusevski',
#   'https://www.basketball-reference.com/players/p/pokusal01.html'),
#  ('Aleksej Pokusevski',
#   'https://www.basketball-reference.com/players/p/pokusal01.html'),
#  ('Jontay Porter',
#   'https://www.basketball-reference.com/players/p/portejo01.html'),
#  ('Bobby Portis',
#   'https://www.basketball-reference.com/players/p/portibo01.html'),
#  ('Micah Potter',
#   'https://www.basketball-reference.com/players/p/pottemi01.html'),
#  ('Taurean Prince',
#   'https://www.basketball-reference.com/players/p/princta02.html'),
#  ('Olivier-Maxence Prosper',
#   'https://www.basketball-reference.com/players/p/prospol01.html'),
#  ('Julius Randle',
#   'https://www.basketball-reference.com/players/r/randlju01.html'),
#  ('Jeremiah Robinson-Earl',
#   'https://www.basketball-reference.com/players/r/robinje02.html'),
#  ('David Roddy',
#   'https://www.basketball-reference.com/players/r/roddyda01.html'),
#  ('David Roddy',
#   'https://www.basketball-reference.com/players/r/roddyda01.html'),
#  ('David Roddy',
#   'https://www.basketball-reference.com/players/r/roddyda01.html'),
#  ('Luka Šamanić',
#   'https://www.basketball-reference.com/players/s/samanlu01.html'),
#  ('Adama Sanogo',
#   'https://www.basketball-reference.com/players/s/sanogad01.html'),
#  ('Gui Santos',
#   'https://www.basketball-reference.com/players/s/santogu01.html'),
#  ('Admiral Schofield',
#   'https://www.basketball-reference.com/players/s/schofad01.html'),
#  ('Pascal Siakam',
#   'https://www.basketball-reference.com/players/s/siakapa01.html'),
#  ('Pascal Siakam',
#   'https://www.basketball-reference.com/players/s/siakapa01.html'),
#  ('Pascal Siakam',
#   'https://www.basketball-reference.com/players/s/siakapa01.html'),
#  ('Jabari Smith Jr.',
#   'https://www.basketball-reference.com/players/s/smithja05.html'),
#  ('Jeremy Sochan',
#   'https://www.basketball-reference.com/players/s/sochaje01.html'),
#  ('Lamar Stevens',
#   'https://www.basketball-reference.com/players/s/stevela01.html'),
#  ('Lamar Stevens',
#   'https://www.basketball-reference.com/players/s/stevela01.html'),
#  ('Lamar Stevens',
#   'https://www.basketball-reference.com/players/s/stevela01.html'),
#  ('Isaiah Stewart',
#   'https://www.basketball-reference.com/players/s/stewais01.html'),
#  ('Jayson Tatum',
#   'https://www.basketball-reference.com/players/t/tatumja01.html'),
#  ('Terry Taylor',
#   'https://www.basketball-reference.com/players/t/taylote01.html'),
#  ('JT Thor', 'https://www.basketball-reference.com/players/t/thorjt01.html'),
#  ('Xavier Tillman Sr.',
#   'https://www.basketball-reference.com/players/t/tillmxa01.html'),
#  ('Xavier Tillman Sr.',
#   'https://www.basketball-reference.com/players/t/tillmxa01.html'),
#  ('Obi Toppin',
#   'https://www.basketball-reference.com/players/t/toppiob01.html'),
#  ('Karl-Anthony Towns',
#   'https://www.basketball-reference.com/players/t/townska01.html'),
#  ('Oscar Tshiebwe',
#   'https://www.basketball-reference.com/players/t/tshieos01.html'),
#  ('P.J. Tucker',
#   'https://www.basketball-reference.com/players/t/tuckepj01.html'),
#  ('P.J. Tucker',
#   'https://www.basketball-reference.com/players/t/tuckepj01.html'),
#  ('P.J. Tucker',
#   'https://www.basketball-reference.com/players/t/tuckepj01.html'),
#  ('Hunter Tyson',
#   'https://www.basketball-reference.com/players/t/tysonhu01.html'),
#  ('Jarred Vanderbilt',
#   'https://www.basketball-reference.com/players/v/vandeja01.html'),
#  ('Sasha Vezenkov',
#   'https://www.basketball-reference.com/players/v/vezenal01.html'),
#  ('Dean Wade', 'https://www.basketball-reference.com/players/w/wadede01.html'),
#  ('Jarace Walker',
#   'https://www.basketball-reference.com/players/w/walkeja02.html'),
#  ('P.J. Washington',
#   'https://www.basketball-reference.com/players/w/washipj01.html'),
#  ('P.J. Washington',
#   'https://www.basketball-reference.com/players/w/washipj01.html'),
#  ('P.J. Washington',
#   'https://www.basketball-reference.com/players/w/washipj01.html'),
#  ('Trendon Watford',
#   'https://www.basketball-reference.com/players/w/watfotr01.html'),
#  ('Grant Williams',
#   'https://www.basketball-reference.com/players/w/willigr01.html'),
#  ('Grant Williams',
#   'https://www.basketball-reference.com/players/w/willigr01.html'),
#  ('Grant Williams',
#   'https://www.basketball-reference.com/players/w/willigr01.html'),
#  ('Jalen Williams',
#   'https://www.basketball-reference.com/players/w/willija06.html'),
#  ('Kenrich Williams',
#   'https://www.basketball-reference.com/players/w/willike04.html'),
#  ('Patrick Williams',
#   'https://www.basketball-reference.com/players/w/willipa01.html'),
#  ('Zion Williamson',
#   'https://www.basketball-reference.com/players/w/willizi01.html'),
#  ('D.J. Wilson',
#   'https://www.basketball-reference.com/players/w/wilsodj01.html'),
#  ('Jalen Wilson',
#   'https://www.basketball-reference.com/players/w/wilsoja03.html'),
#  ('Christian Wood',
#   'https://www.basketball-reference.com/players/w/woodch01.html'),
#  ('Thaddeus Young',
#   'https://www.basketball-reference.com/players/y/youngth01.html'),
#  ('Thaddeus Young',
#   'https://www.basketball-reference.com/players/y/youngth01.html'),
#  ('Thaddeus Young',
#   'https://www.basketball-reference.com/players/y/youngth01.html')]

# %%
# Get the shooting dataframe for the 2023-24 power forwards
shooting_data_dfs_2024 = {}
for pf in pf_players_2024:
    if pf[0] not in shooting_data_dfs_2024.keys():
        shooting_data_dfs_2024[pf[0]] = get_shooting_data(pf[1], '2023-24', pf[0])

shooting_data_2024 = pd.concat(shooting_data_dfs_2024.values())
shooting_data_2024
# Out:
#                        Age   Tm   Lg   Pos   G    MP   FG% Dist.  \
# Player
# Precious Achiuwa        24  TOT  NBA  C,PF  74  1624  .501   7.6
# Santi Aldama            23  MEM  NBA    PF  61  1618  .435  15.8
# Kyle Anderson           30  MIN  NBA    PF  79  1782  .460   9.0
# Giannis Antetokounmpo   29  MIL  NBA    PF  73  2567  .611   6.7
# Thanasis Antetokounmpo  31  MIL  NBA    PF  34   155  .533   3.7
# ...                     ..  ...  ...   ...  ..   ...   ...   ...
# Zion Williamson         23  NOP  NBA    PF  70  2207  .570   4.0
# D.J. Wilson             27  PHI  NBA    PF   2    15  .667  10.3
# Jalen Wilson            23  BRK  NBA    PF  43   664  .425  14.0
# Christian Wood          28  LAL  NBA    PF  50   872  .466  13.8
# Thaddeus Young          35  TOT  NBA    PF  33   439  .602   4.8
#
#                        % of FGA by Distance: 2P % of FGA by Distance: 0-3ft  \
# Player
# Precious Achiuwa                           .793                        .520
# Santi Aldama                               .465                        .211
# Kyle Anderson                              .889                        .192
# Giannis Antetokounmpo                      .909                        .519
# Thanasis Antetokounmpo                     .967                        .767
# ...                                         ...                         ...
# Zion Williamson                            .984                        .547
# D.J. Wilson                                .667                        .333
# Jalen Wilson                               .587                        .229
# Christian Wood                             .568                        .261
# Thaddeus Young                             .935                        .528
#
#                         ... % of FGA by Distance: 16-3P  \
# Player                  ...
# Precious Achiuwa        ...                        .011
# Santi Aldama            ...                        .016
# Kyle Anderson           ...                        .028
# Giannis Antetokounmpo   ...                        .072
# Thanasis Antetokounmpo  ...                        .033
# ...                     ...                         ...
# Zion Williamson         ...                        .003
# D.J. Wilson             ...                        .000
# Jalen Wilson            ...                        .022
# Christian Wood          ...                        .042
# Thaddeus Young          ...                        .009
#
#                        % of FGA by Distance: 3P FG% by Distance: 2P  \
# Player
# Precious Achiuwa                           .207                .562
# Santi Aldama                               .535                .534
# Kyle Anderson                              .111                .488
# Giannis Antetokounmpo                      .091                .645
# Thanasis Antetokounmpo                     .033                .552
# ...                                         ...                 ...
# Zion Williamson                            .016                .574
# D.J. Wilson                                .333                .500
# Jalen Wilson                               .413                .495
# Christian Wood                             .432                .587
# Thaddeus Young                             .065                .634
#
#                        FG% by Distance: 0-3ft FG% by Distance: 3-10ft  \
# Player
# Precious Achiuwa                         .697                    .317
# Santi Aldama                             .692                    .411
# Kyle Anderson                            .627                    .438
# Giannis Antetokounmpo                    .818                    .452
# Thanasis Antetokounmpo                   .609                    .400
# ...                                       ...                     ...
# Zion Williamson                          .717                    .396
# D.J. Wilson                             1.000                    .000
# Jalen Wilson                             .683                    .356
# Christian Wood                           .812                    .424
# Thaddeus Young                           .667                    .611
#
#                        FG% by Distance: 10-16ft FG% by Distance: 16-3P  \
# Player
# Precious Achiuwa                           .273                   .200
# Santi Aldama                               .393                   .333
# Kyle Anderson                              .476                   .500
# Giannis Antetokounmpo                      .323                   .374
# Thanasis Antetokounmpo                                            .000
# ...                                         ...                    ...
# Zion Williamson                            .394                   .333
# D.J. Wilson
# Jalen Wilson                               .400                   .500
# Christian Wood                             .455                   .182
# Thaddeus Young                             .429                  1.000
#
#                        FG% by Distance: 3P % of FG Ast'd: 2P % of FG Ast'd: 3P
# Player
# Precious Achiuwa                      .268              .593              .962
# Santi Aldama                          .349              .674              .962
# Kyle Anderson                         .229              .511             1.000
# Giannis Antetokounmpo                 .274              .509              .500
# Thanasis Antetokounmpo                .000              .750
# ...                                    ...               ...               ...
# Zion Williamson                       .333              .474              .833
# D.J. Wilson                          1.000             1.000             1.000
# Jalen Wilson                          .324              .615             1.000
# Christian Wood                        .307              .761              .971
# Thaddeus Young                        .143              .734             1.000
#
# [116 rows x 22 columns]

# %%
shooting_data_2014.to_csv(r'C:\Users\vaugh\Desktop\basketball-pf-research\bball-ref_data_2014.csv')

# %%
shooting_data_2024.to_csv(r'C:\Users\vaugh\Desktop\basketball-pf-research\bball-ref_data_2024.csv')
