# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
import time
import numpy as np
import matplotlib.pyplot as plt
import html5lib

nba_teams = {
    'Miami Heat': 'MIA',
    'Chicago Bulls': 'CHI',
    'Philadelphia 76ers': 'PHI',
    'New Jersey Nets': 'NJN',
    'Golden State Warriors': 'GSW',
    'Boston Celtics': 'BOS',
    'Indiana Pacers': 'IND',
    'Atlanta Hawks': 'ATL',
    'New York Knicks': 'NYK',
    'Toronto Raptors': 'TOR',
    'Cleveland Cavaliers': 'CLE',
    'Orlando Magic': 'ORL',
    'Phoenix Suns': 'PHO',
    'Denver Nuggets': 'DEN',
    'Houston Rockets': 'HOU',
    'Minnesota Timberwolves': 'MIN',
    'San Antonio Spurs': 'SAS',
    'Portland Trail Blazers': 'POR',
    'Sacramento Kings': 'SAC',
    'Charlotte Hornets': 'CHH',
    'Detroit Pistons': 'DET',
    'Dallas Mavericks': 'DAL',
    'Seattle SuperSonics': 'SEA',
    'Vancouver Grizzlies': 'VAN',
    'Los Angeles Lakers': 'LAL',
    'Los Angeles Clippers': 'LAC',
    'Utah Jazz': 'UTA',
    'Washington Wizards': 'WAS',
    'Milwaukee Bucks': 'MIL',
    'Memphis Grizzlies': 'MEM',
    'New Orleans Hornets': 'NOH',
    'New Orleans/Oklahoma City Hornets': 'NOK',
    'Oklahoma City Thunder': 'OKC',
    'Brooklyn Nets': 'BRK',
    'New Orleans Pelicans': 'NOP',
    'Charlotte Bobcats': 'CHO'
}

# Create a function to scrape the data from a basketball-reference page
def get_bballref_records_df(url):
    # Initialize the selenium driver
    driver = webdriver.Chrome()
    
    start_time = time.time()  # Record start time
    max_wait_time = 60  # Maximum wait time in seconds
    
    try:
        # Open the specified page
        driver.get(url)
        
        # Continuously check the time until the page is fully loaded
        while True:
            elapsed_time = time.time() - start_time
            if elapsed_time > max_wait_time:
                print(f"Timeout reached for {url}. Retrying...")
                driver.quit()
                return get_bballref_df(url)
            
            # Check if page is loaded
            if driver.execute_script("return document.readyState;") == "complete":
                break
            
            time.sleep(1)  # Wait a bit before checking again
            
        # Parse with BeautifulSoup
        soup = BeautifulSoup(driver.page_source, 'html')
    
    except Exception as e:
        print(f"Error for {url}: {e}")
        driver.quit()
        return get_bballref_df(url)

    finally:
        driver.quit()
    
    # Find the table
    table = soup.find('table', {'id': 'expanded_standings'})
    
    # Parse the table data
    df = pd.read_html(str(table))[0]  # Converts HTML table to DataFrame
    
    df.columns = df.columns.map(' - '.join)
    for column in df.columns:
        if 'Unnamed' in column:
            new_column_name = column.split(' - ')[1]
            df.rename(columns={column: new_column_name}, inplace=True)
    
    # Cleaning up the dataframes
    for column in df.columns:
        if 'Unnamed' in column:
            df.drop(columns=[column], inplace=True)
    
    df = df.drop(columns = [column for column in df.columns if column not in ['Team', 'Overall']])
    
    df['Tm'] = df['Team'].map(nba_teams)
    
    return df

# %%
seasons = ['2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024']
season_records_dfs = {}
for season in seasons:
    if season in ['2001', '2002']:
        nba_teams['Charlotte Hornets'] = 'CHH'
    else:
        nba_teams['Charlotte Hornets'] = 'CHA'
    season_records_dfs[season] = get_bballref_records_df(f'https://www.basketball-reference.com/leagues/NBA_{season}_standings.html')

# %%
processed_dfs = []

for season, df in season_records_dfs.items():
    # Create the new index as 'Rank-Statistic'
    df['Rank-Statistic'] = season + '-' + df['Tm']
    # Keep only 'Rank-Statistic' as the index and 'Overall' column
    processed_dfs.append(df.set_index('Rank-Statistic')[['Overall']])

# Concatenate all the processed DataFrames
result_df = pd.concat(processed_dfs)

# %%
result_df.to_csv(r"C:\Users\vaugh\Desktop\basketball-pf-research\Basketball-reference data\team_records_2001-2024.csv")

# %%
season_records_dfs
# Out:
# {'2001':                       Team Overall   Tm
#  0        San Antonio Spurs   58-24  SAS
#  1       Los Angeles Lakers   56-26  LAL
#  2       Philadelphia 76ers   56-26  PHI
#  3         Sacramento Kings   55-27  SAC
#  4         Dallas Mavericks   53-29  DAL
#  5                Utah Jazz   53-29  UTA
#  6          Milwaukee Bucks   52-30  MIL
#  7             Phoenix Suns   51-31  PHO
#  8               Miami Heat   50-32  MIA
#  9   Portland Trail Blazers   50-32  POR
#  10         New York Knicks   48-34  NYK
#  11  Minnesota Timberwolves   47-35  MIN
#  12         Toronto Raptors   47-35  TOR
#  13       Charlotte Hornets   46-36  CHH
#  14         Houston Rockets   45-37  HOU
#  15     Seattle SuperSonics   44-38  SEA
#  16           Orlando Magic   43-39  ORL
#  17          Indiana Pacers   41-41  IND
#  18          Denver Nuggets   40-42  DEN
#  19          Boston Celtics   36-46  BOS
#  20         Detroit Pistons   32-50  DET
#  21    Los Angeles Clippers   31-51  LAC
#  22     Cleveland Cavaliers   30-52  CLE
#  23         New Jersey Nets   26-56  NJN
#  24           Atlanta Hawks   25-57  ATL
#  25     Vancouver Grizzlies   23-59  VAN
#  26      Washington Wizards   19-63  WAS
#  27   Golden State Warriors   17-65  GSW
#  28           Chicago Bulls   15-67  CHI,
#  '2002':                       Team Overall   Tm
#  0         Sacramento Kings   61-21  SAC
#  1       Los Angeles Lakers   58-24  LAL
#  2        San Antonio Spurs   58-24  SAS
#  3         Dallas Mavericks   57-25  DAL
#  4          New Jersey Nets   52-30  NJN
#  5          Detroit Pistons   50-32  DET
#  6   Minnesota Timberwolves   50-32  MIN
#  7           Boston Celtics   49-33  BOS
#  8   Portland Trail Blazers   49-33  POR
#  9      Seattle SuperSonics   45-37  SEA
#  10       Charlotte Hornets   44-38  CHH
#  11           Orlando Magic   44-38  ORL
#  12               Utah Jazz   44-38  UTA
#  13      Philadelphia 76ers   43-39  PHI
#  14          Indiana Pacers   42-40  IND
#  15         Toronto Raptors   42-40  TOR
#  16         Milwaukee Bucks   41-41  MIL
#  17    Los Angeles Clippers   39-43  LAC
#  18      Washington Wizards   37-45  WAS
#  19              Miami Heat   36-46  MIA
#  20            Phoenix Suns   36-46  PHO
#  21           Atlanta Hawks   33-49  ATL
#  22         New York Knicks   30-52  NYK
#  23     Cleveland Cavaliers   29-53  CLE
#  24         Houston Rockets   28-54  HOU
#  25          Denver Nuggets   27-55  DEN
#  26       Memphis Grizzlies   23-59  MEM
#  27           Chicago Bulls   21-61  CHI
#  28   Golden State Warriors   21-61  GSW,
#  '2003':                       Team Overall   Tm
#  0         Dallas Mavericks   60-22  DAL
#  1        San Antonio Spurs   60-22  SAS
#  2         Sacramento Kings   59-23  SAC
#  3   Minnesota Timberwolves   51-31  MIN
#  4          Detroit Pistons   50-32  DET
#  5       Los Angeles Lakers   50-32  LAL
#  6   Portland Trail Blazers   50-32  POR
#  7          New Jersey Nets   49-33  NJN
#  8           Indiana Pacers   48-34  IND
#  9       Philadelphia 76ers   48-34  PHI
#  10     New Orleans Hornets   47-35  NOH
#  11               Utah Jazz   47-35  UTA
#  12          Boston Celtics   44-38  BOS
#  13            Phoenix Suns   44-38  PHO
#  14         Houston Rockets   43-39  HOU
#  15         Milwaukee Bucks   42-40  MIL
#  16           Orlando Magic   42-40  ORL
#  17     Seattle SuperSonics   40-42  SEA
#  18   Golden State Warriors   38-44  GSW
#  19         New York Knicks   37-45  NYK
#  20      Washington Wizards   37-45  WAS
#  21           Atlanta Hawks   35-47  ATL
#  22           Chicago Bulls   30-52  CHI
#  23       Memphis Grizzlies   28-54  MEM
#  24    Los Angeles Clippers   27-55  LAC
#  25              Miami Heat   25-57  MIA
#  26         Toronto Raptors   24-58  TOR
#  27     Cleveland Cavaliers   17-65  CLE
#  28          Denver Nuggets   17-65  DEN,
#  '2004':                       Team Overall   Tm
#  0           Indiana Pacers   61-21  IND
#  1   Minnesota Timberwolves   58-24  MIN
#  2        San Antonio Spurs   57-25  SAS
#  3       Los Angeles Lakers   56-26  LAL
#  4         Sacramento Kings   55-27  SAC
#  5          Detroit Pistons   54-28  DET
#  6         Dallas Mavericks   52-30  DAL
#  7        Memphis Grizzlies   50-32  MEM
#  8          New Jersey Nets   47-35  NJN
#  9          Houston Rockets   45-37  HOU
#  10          Denver Nuggets   43-39  DEN
#  11              Miami Heat   42-40  MIA
#  12               Utah Jazz   42-40  UTA
#  13         Milwaukee Bucks   41-41  MIL
#  14     New Orleans Hornets   41-41  NOH
#  15  Portland Trail Blazers   41-41  POR
#  16         New York Knicks   39-43  NYK
#  17   Golden State Warriors   37-45  GSW
#  18     Seattle SuperSonics   37-45  SEA
#  19          Boston Celtics   36-46  BOS
#  20     Cleveland Cavaliers   35-47  CLE
#  21      Philadelphia 76ers   33-49  PHI
#  22         Toronto Raptors   33-49  TOR
#  23            Phoenix Suns   29-53  PHO
#  24           Atlanta Hawks   28-54  ATL
#  25    Los Angeles Clippers   28-54  LAC
#  26      Washington Wizards   25-57  WAS
#  27           Chicago Bulls   23-59  CHI
#  28           Orlando Magic   21-61  ORL,
#  '2005':                       Team  Overall   Tm
#  0             Phoenix Suns    62-20  PHO
#  1               Miami Heat    59-23  MIA
#  2        San Antonio Spurs    59-23  SAS
#  3         Dallas Mavericks    58-24  DAL
#  4          Detroit Pistons    54-28  DET
#  5      Seattle SuperSonics    52-30  SEA
#  6          Houston Rockets    51-31  HOU
#  7         Sacramento Kings    50-32  SAC
#  8           Denver Nuggets    49-33  DEN
#  9            Chicago Bulls    47-35  CHI
#  10          Boston Celtics    45-37  BOS
#  11       Memphis Grizzlies    45-37  MEM
#  12      Washington Wizards    45-37  WAS
#  13          Indiana Pacers    44-38  IND
#  14  Minnesota Timberwolves    44-38  MIN
#  15      Philadelphia 76ers    43-39  PHI
#  16         New Jersey Nets    42-40  NJN
#  17     Cleveland Cavaliers    42-40  CLE
#  18    Los Angeles Clippers    37-45  LAC
#  19           Orlando Magic    36-46  ORL
#  20                     NaN      NaN  NaN
#  21                    Team  Overall  NaN
#  
#  20                     NaN      NaN  NaN
#  21                    Team  Overall  NaN
#  22    New Orleans Pelicans    34-48  NOP
#  23     Cleveland Cavaliers    33-49  CLE
#  24         Detroit Pistons    29-53  DET
#  25        Sacramento Kings    28-54  SAC
#  26      Los Angeles Lakers    27-55  LAL
#  27          Boston Celtics    25-57  BOS
#  28               Utah Jazz    25-57  UTA
#  29           Orlando Magic    23-59  ORL
#  30      Philadelphia 76ers    19-63  PHI
#  31         Milwaukee Bucks    15-67  MIL,
#  '2015':                       Team  Overall   Tm
#  0    Golden State Warriors    67-15  GSW
#  1            Atlanta Hawks    60-22  ATL
#  2          Houston Rockets    56-26  HOU
#  3     Los Angeles Clippers    56-26  LAC
#  4        Memphis Grizzlies    55-27  MEM
#  5        San Antonio Spurs    55-27  SAS
#  6      Cleveland Cavaliers    53-29  CLE
#  7   Portland Trail Blazers    51-31  POR
#  8            Chicago Bulls    50-32  CHI
#  9         Dallas Mavericks    50-32  DAL
#  10         Toronto Raptors    49-33  TOR
#  11      Washington Wizards    46-36  WAS
#  12    New Orleans Pelicans    45-37  NOP
#  13   Oklahoma City Thunder    45-37  OKC
#  14         Milwaukee Bucks    41-41  MIL
#  15          Boston Celtics    40-42  BOS
#  16            Phoenix Suns    39-43  PHO
#  17           Brooklyn Nets    38-44  BRK
#  18          Indiana Pacers    38-44  IND
#  19               Utah Jazz    38-44  UTA
#  20                     NaN      NaN  NaN
#  21                    Team  Overall  NaN
#  22              Miami Heat    37-45  MIA
#  23       Charlotte Hornets    33-49  CHA
#  24         Detroit Pistons    32-50  DET
#  25          Denver Nuggets    30-52  DEN
#  26        Sacramento Kings    29-53  SAC
#  27           Orlando Magic    25-57  ORL
#  28      Los Angeles Lakers    21-61  LAL
#  29      Philadelphia 76ers    18-64  PHI
#  30         New York Knicks    17-65  NYK
#  31  Minnesota Timberwolves    16-66  MIN,
#  '2016':                       Team  Overall   Tm
#  0    Golden State Warriors     73-9  GSW
#  1        San Antonio Spurs    67-15  SAS
#  2      Cleveland Cavaliers    57-25  CLE
#  3          Toronto Raptors    56-26  TOR
#  4    Oklahoma City Thunder    55-27  OKC
#  5     Los Angeles Clippers    53-29  LAC
#  6            Atlanta Hawks    48-34  ATL
#  7           Boston Celtics    48-34  BOS
#  8        Charlotte Hornets    48-34  CHA
#  9               Miami Heat    48-34  MIA
#  10          Indiana Pacers    45-37  IND
#  11         Detroit Pistons    44-38  DET
#  12  Portland Trail Blazers    44-38  POR
#  13        Dallas Mavericks    42-40  DAL
#  14       Memphis Grizzlies    42-40  MEM
#  15           Chicago Bulls    42-40  CHI
#  16         Houston Rockets    41-41  HOU
#  17      Washington Wizards    41-41  WAS
#  18               Utah Jazz    40-42  UTA
#  19           Orlando Magic    35-47  ORL
#  20                     NaN      NaN  NaN
#  21                    Team  Overall  NaN
#  22          Denver Nuggets    33-49  DEN
#  23         Milwaukee Bucks    33-49  MIL
#  24        Sacramento Kings    33-49  SAC
#  25         New York Knicks    32-50  NYK
#  26    New Orleans Pelicans    30-52  NOP
#  27  Minnesota Timberwolves    29-53  MIN
#  28            Phoenix Suns    23-59  PHO
#  29           Brooklyn Nets    21-61  BRK
#  30      Los Angeles Lakers    17-65  LAL
#  31      Philadelphia 76ers    10-72  PHI,
#  20                     NaN      NaN  NaN
#  21                    Team  Overall  NaN
#  22           Chicago Bulls    31-41  CHI
#  23    New Orleans Pelicans    31-41  NOP
#  24        Sacramento Kings    31-41  SAC
#  25         Toronto Raptors    27-45  TOR
#  26  Minnesota Timberwolves    23-49  MIN
#  27     Cleveland Cavaliers    22-50  CLE
#  28   Oklahoma City Thunder    22-50  OKC
#  29           Orlando Magic    21-51  ORL
#  30         Detroit Pistons    20-52  DET
#  31         Houston Rockets    17-55  HOU,
#  '2022':                       Team  Overall   Tm
#  0             Phoenix Suns    64-18  PHO
#  1        Memphis Grizzlies    56-26  MEM
#  2    Golden State Warriors    53-29  GSW
#  3               Miami Heat    53-29  MIA
#  4         Dallas Mavericks    52-30  DAL
#  5           Boston Celtics    51-31  BOS
#  6          Milwaukee Bucks    51-31  MIL
#  7       Philadelphia 76ers    51-31  PHI
#  8                Utah Jazz    49-33  UTA
#  9           Denver Nuggets    48-34  DEN
#  10         Toronto Raptors    48-34  TOR
#  11           Chicago Bulls    46-36  CHI
#  12  Minnesota Timberwolves    46-36  MIN
#  13           Brooklyn Nets    44-38  BRK
#  14     Cleveland Cavaliers    44-38  CLE
#  15           Atlanta Hawks    43-39  ATL
#  16       Charlotte Hornets    43-39  CHA
#  17    Los Angeles Clippers    42-40  LAC
#  18         New York Knicks    37-45  NYK
#  19    New Orleans Pelicans    36-46  NOP
#  20                     NaN      NaN  NaN
#  21                    Team  Overall  NaN
#  22      Washington Wizards    35-47  WAS
#  23       San Antonio Spurs    34-48  SAS
#  24      Los Angeles Lakers    33-49  LAL
#  25        Sacramento Kings    30-52  SAC
#  26  Portland Trail Blazers    27-55  POR
#  27          Indiana Pacers    25-57  IND
#  28   Oklahoma City Thunder    24-58  OKC
#  29         Detroit Pistons    23-59  DET
#  30           Orlando Magic    22-60  ORL
#  31         Houston Rockets    20-62  HOU,
#  '2023':                       Team  Overall   Tm
#  0          Milwaukee Bucks    58-24  MIL
#  1           Boston Celtics    57-25  BOS
#  2       Philadelphia 76ers    54-28  PHI
#  3           Denver Nuggets    53-29  DEN
#  4      Cleveland Cavaliers    51-31  CLE
#  5        Memphis Grizzlies    51-31  MEM
#  6         Sacramento Kings    48-34  SAC
#  7          New York Knicks    47-35  NYK
#  8            Brooklyn Nets    45-37  BRK
#  9             Phoenix Suns    45-37  PHO
#  10   Golden State Warriors    44-38  GSW
#  11    Los Angeles Clippers    44-38  LAC
#  12              Miami Heat    44-38  MIA
#  13      Los Angeles Lakers    43-39  LAL
#  14  Minnesota Timberwolves    42-40  MIN
#  15    New Orleans Pelicans    42-40  NOP
#  16           Atlanta Hawks    41-41  ATL
#  17         Toronto Raptors    41-41  TOR
#  18           Chicago Bulls    40-42  CHI
#  19   Oklahoma City Thunder    40-42  OKC
#  20                     NaN      NaN  NaN
#  21                    Team  Overall  NaN
#  22        Dallas Mavericks    38-44  DAL
#  23               Utah Jazz    37-45  UTA
#  24          Indiana Pacers    35-47  IND
#  25      Washington Wizards    35-47  WAS
#  26           Orlando Magic    34-48  ORL
#  27  Portland Trail Blazers    33-49  POR
#  28       Charlotte Hornets    27-55  CHA
#  29         Houston Rockets    22-60  HOU
#  30       San Antonio Spurs    22-60  SAS
#  31         Detroit Pistons    17-65  DET,
#  '2024':                       Team  Overall   Tm
#  0           Boston Celtics    64-18  BOS
#  1           Denver Nuggets    57-25  DEN
#  2    Oklahoma City Thunder    57-25  OKC
#  3   Minnesota Timberwolves    56-26  MIN
#  4     Los Angeles Clippers    51-31  LAC
#  5         Dallas Mavericks    50-32  DAL
#  6          New York Knicks    50-32  NYK
#  7          Milwaukee Bucks    49-33  MIL
#  8     New Orleans Pelicans    49-33  NOP
#  9             Phoenix Suns    49-33  PHO
#  10     Cleveland Cavaliers    48-34  CLE
#  11          Indiana Pacers    47-35  IND
#  12      Los Angeles Lakers    47-35  LAL
#  13           Orlando Magic    47-35  ORL
#  14      Philadelphia 76ers    47-35  PHI
#  15              Miami Heat    46-36  MIA
#  16   Golden State Warriors    46-36  GSW
#  17        Sacramento Kings    46-36  SAC
#  18         Houston Rockets    41-41  HOU
#  19           Chicago Bulls    39-43  CHI
#  20                     NaN      NaN  NaN
#  21                    Team  Overall  NaN
#  22           Atlanta Hawks    36-46  ATL
#  23           Brooklyn Nets    32-50  BRK
#  24               Utah Jazz    31-51  UTA
#  25       Memphis Grizzlies    27-55  MEM
#  26         Toronto Raptors    25-57  TOR
#  27       San Antonio Spurs    22-60  SAS
#  28       Charlotte Hornets    21-61  CHA
#  29  Portland Trail Blazers    21-61  POR
#  30      Washington Wizards    15-67  WAS
#  31         Detroit Pistons    14-68  DET}

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd
import time
import numpy as np
import matplotlib.pyplot as plt
import html5lib

# Create a function to scrape the data from a basketball-reference page
def get_bballref_df(url, data_type):
    # Initialize the selenium driver
    driver = webdriver.Chrome()
    
    start_time = time.time()  # Record start time
    max_wait_time = 60  # Maximum wait time in seconds
    
    try:
        # Open the specified page
        driver.get(url)
        
        # Continuously check the time until the page is fully loaded
        while True:
            elapsed_time = time.time() - start_time
            if elapsed_time > max_wait_time:
                print(f"Timeout reached for {url}. Retrying...")
                driver.quit()
                return get_bballref_df(url, data_type)
            
            # Check if page is loaded
            if driver.execute_script("return document.readyState;") == "complete":
                break
            
            time.sleep(1)  # Wait a bit before checking again
            
        # Parse with BeautifulSoup
        soup = BeautifulSoup(driver.page_source, 'html')
    
    except Exception as e:
        print(f"Error for {url}: {e}")
        driver.quit()
        return get_bballref_df(url, data_type)

    finally:
        driver.quit()
    
    if (data_type in ['advanced', 'shooting']):
        table=soup.find('table', {'id': data_type})
    else:
        # Find the table's container div by ID
        div_id = "switcher_" + data_type  # Adjusting based on your `data_type`
        table_div = soup.find('div', {'id': div_id})
        if table_div is None:
            print(f"Could not find table div with id {div_id}.")
            return None
    
        # Find the table
        table = table_div.find('table', {'id': data_type})
    
    # Parse the table data
    df = pd.read_html(str(table))[0]  # Converts HTML table to DataFrame
    
    # Additional cleaning only needed for the shooting stats and play-by-play stats
    if data_type == 'shooting' or data_type == 'pbp_stats':
        df.columns = df.columns.map(' - '.join)
        for column in df.columns:
            if 'Unnamed' in column:
                new_column_name = column.split(' - ')[1]
                df.rename(columns={column: new_column_name}, inplace=True)
    
    # Cleaning up the dataframes
    for column in df.columns:
        if 'Unnamed' in column:
            df.drop(columns=[column], inplace=True)
    
    return df

# %%
# List out all the seasons we want data from
seasons = ['2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024']
tables = ['advanced', 'shooting', 'play-by-play', 'per_game']

# Create a helper function to keep players' stats from each team they played for in a single season
def drop_tot_rows(group):
    group['Team'] = group['Team'].astype(str)
    group = group[(group['Team'] != 'nan') & (group['Team'] != 'Team')]
    return group[~group['Team'].str.endswith('TM')]

# Create a dictionary to store all the dataframes
bballref_dfs = {}

# Go through and extract the data from every season for the 4 desired categories
for data in tables:
    for season in seasons:
        url = f'https://www.basketball-reference.com/leagues/NBA_{season}_{data}.html'
        if data == 'play-by-play':
            df = get_bballref_df(url, 'pbp_stats')
        elif data in ['advanced', 'shooting']:
            df = get_bballref_df(url, data)
        else:
            df = get_bballref_df(url, data + '_stats')
        df['Player'] = df['Player'].str.replace(r'\*$', '', regex=True)
        df = df.groupby('Player', group_keys=False).apply(drop_tot_rows)
        if data == 'advanced':
            df.drop(columns = ['Rk', 'Age', 'TS%', '3PAr', 'PER', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'OWS', 'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM', 'VORP'], inplace=True)
        elif data == 'shooting':
            df.drop(columns = ['G', 'MP', 'Team', 'Dist.', 'Rk', 'Age', 'Pos',  'FG% by Distance - 2P', 'FG% by Distance - 0-3', 'FG% by Distance - 3-10', 'FG% by Distance - 10-16', 'FG% by Distance - 16-3P', 'FG% by Distance - 3P', 'FG%', 'Dunks - #', 'Heaves - Att.', 'Heaves - Md.', 'Corner 3s - 3P%'], inplace=True)
        elif data == 'play-by-play':
            df.drop(columns = ['G', 'MP', 'Rk', 'Team', 'Age', 'Pos', '+/- Per 100 Poss - OnCourt', '+/- Per 100 Poss - On-Off', 'Turnovers - BadPass', 'Turnovers - LostBall', 'Fouls Committed - Shoot', 'Fouls Committed - Off.', 'Misc. - PGA', 'Misc. - And1', 'Misc. - Blkd', 'Awards'], inplace=True)
        else:
            df.drop(columns = ['G', 'MP', 'Rk', 'Team', 'Age', 'Pos', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'TRB', 'PTS', 'Awards'], inplace=True)
        bballref_dfs[season + data] = df
# Out:
# Timeout reached for https://www.basketball-reference.com/leagues/NBA_2011_advanced.html. Retrying...
# Timeout reached for https://www.basketball-reference.com/leagues/NBA_2015_advanced.html. Retrying...
# Timeout reached for https://www.basketball-reference.com/leagues/NBA_2017_advanced.html. Retrying...
# Timeout reached for https://www.basketball-reference.com/leagues/NBA_2017_advanced.html. Retrying...
# Timeout reached for https://www.basketball-reference.com/leagues/NBA_2017_advanced.html. Retrying...
# Timeout reached for https://www.basketball-reference.com/leagues/NBA_2006_play-by-play.html. Retrying...
# Timeout reached for https://www.basketball-reference.com/leagues/NBA_2015_play-by-play.html. Retrying...
# Timeout reached for https://www.basketball-reference.com/leagues/NBA_2021_play-by-play.html. Retrying...
# Timeout reached for https://www.basketball-reference.com/leagues/NBA_2002_per_game.html. Retrying...
# Timeout reached for https://www.basketball-reference.com/leagues/NBA_2020_per_game.html. Retrying...
# Timeout reached for https://www.basketball-reference.com/leagues/NBA_2021_per_game.html. Retrying...
# Timeout reached for https://www.basketball-reference.com/leagues/NBA_2023_per_game.html. Retrying...

# %%
for season in seasons:
    for data in tables:
        if data != 'advanced':
            bballref_dfs[season + data] = bballref_dfs[season + data].drop(columns=['Team'])

# %%
separated_dfs_by_season['2024']['2024per_game'][separated_dfs_by_season['2024']['2024per_game']['Player'] == 'Spencer Dinwiddie']
# Out:
#                 Player  GS   FG   FGA  ORB  DRB  AST  STL  BLK  TOV   PF
# 740  Spencer Dinwiddie  48  4.1  10.4  0.5  2.8  6.0  0.8  0.2  1.3  1.8
# 742  Spencer Dinwiddie   4  2.0   5.0  0.1  1.5  2.4  0.5  0.5  1.0  1.9

# %%
separated_dfs_by_season = {}
for season in seasons:
    separated_dfs_by_season[season] = {}
    for df in bballref_dfs:
        if season in df:
            separated_dfs_by_season[season][df] = bballref_dfs[df]

# %%
for season in seasons:
    for df in separated_dfs_by_season[season]:
        if 'advanced' not in df:
            separated_dfs_by_season[season][df] = separated_dfs_by_season[season][df].drop_duplicates(subset=['Player', 'GS'], keep='first')

# %%
# Remove 'Unnamed: 0' columns from each dataframe in the dictionary
for season in separated_dfs_by_season:
    for df in separated_dfs_by_season[season]:
        separated_dfs_by_season[season][df] = separated_dfs_by_season[season][df].drop(columns=[col for col in separated_dfs_by_season[season][df].columns if 'Unnamed' in col])
        separated_dfs_by_season[season][df]['GS'] = separated_dfs_by_season[season][df]['GS'].astype(str)

# %%
separated_dfs_by_season['2024']
# Out:
# {'2024advanced':               Player Team Pos   G  GS    MP   FTr  USG% Awards
#  449       A.J. Green  MIL  SG  56   0   614  .097  15.2    NaN
#  565      A.J. Lawson  DAL  SG  42   0   311  .190  20.0    NaN
#  615       AJ Griffin  ATL  SF  20   0   171  .032  17.3    NaN
#  60      Aaron Gordon  DEN  PF  73  73  2297  .376  17.8    NaN
#  273    Aaron Holiday  HOU  PG  78   1  1269  .151  16.7    NaN
#  ..               ...  ...  ..  ..  ..   ...   ...   ...    ...
#  378      Zach LaVine  CHI  SG  25  23   872  .274  23.8    NaN
#  618   Zavier Simpson  MEM  PG   7   0   161  .074  17.5    NaN
#  468       Zeke Nnaji  DEN  PF  58   0   576  .416  15.4    NaN
#  328  Ziaire Williams  MEM  SF  51  15  1038  .198  19.7    NaN
#  77   Zion Williamson  NOP  PF  70  70  2207  .452  29.7    NaN
#
#  [657 rows x 9 columns],
#  '2024shooting':               Player  GS % of FGA by Distance - 2P % of FGA by Distance - 0-3  \
#  0         A.J. Green   0                      .138                       .026
#  1        A.J. Lawson   0                      .587                       .364
#  2         AJ Griffin   0                      .371                       .048
#  3       Aaron Gordon  73                      .807                       .554
#  4      Aaron Holiday   1                      .480                       .122
#  ..               ...  ..                       ...                        ...
#  836      Zach LaVine  23                      .551                       .237
#  837   Zavier Simpson   0                      .685                       .167
#  838       Zeke Nnaji   0                      .846                       .597
#  839  Ziaire Williams  15                      .500                       .220
#  840  Zion Williamson  70                      .984                       .547
#
#      % of FGA by Distance - 3-10 % of FGA by Distance - 10-16  \
#  0                          .020                         .031
#  1                          .198                         .008
#  2                          .194                         .065
#  3                          .183                         .053
#  4                          .170                         .139
#  ..                          ...                          ...
#  836                        .136                         .053
#  837                        .333                         .093
#  838                        .215                         .027
#  839                        .127                         .085
#  840                        .404                         .030
#
#      % of FGA by Distance - 16-3P % of FGA by Distance - 3P % of FG Ast'd - 2P  \
#  0                           .061                      .862               .857
#  1                           .017                      .413               .610
#  2                           .065                      .629               .750
#  3                           .017                      .193               .642
#  4                           .048                      .520               .255
#  ..                           ...                       ...                ...
#  836                         .125                      .449               .396
#  837                         .093                      .315               .250
#  838                         .007                      .154               .619
#  839                         .069                      .500               .641
#  840                         .003                      .016               .474
#
#      % of FG Ast'd - 3P Dunks - %FGA Corner 3s - %3PA Awards
#  0                 .942         .000             .225    NaN
#  1                1.000         .107             .640    NaN
#  2                 .800         .016             .205    NaN
#  3                 .850         .256             .391    NaN
#  4                 .810         .005             .212    NaN
#  ..                 ...          ...              ...    ...
#  836               .525         .040             .183    NaN
#  837               .800         .019             .118    NaN
#  838              1.000         .181             .391    NaN
#  839               .897         .095             .370    NaN
#  840               .833         .080             .111    NaN
#
#  [629 rows x 13 columns],
#  '2024play-by-play':               Player  GS Position Estimate - PG% Position Estimate - SG%  \
#  0         A.J. Green   0                      20                      65
#  1        A.J. Lawson   0                       6                      41
#  2         AJ Griffin   0                       0                       5
#  3       Aaron Gordon  73                       0                       0
#  4      Aaron Holiday   1                     100                       0
#  ..               ...  ..                     ...                     ...
#  836      Zach LaVine  23                       0                      41
#  837   Zavier Simpson   0                     100                       0
#  838       Zeke Nnaji   0                       0                       0
#  839  Ziaire Williams  15                       0                      23
#  840  Zion Williamson  70                       0                       0
#
#      Position Estimate - SF% Position Estimate - PF% Position Estimate - C%  \
#  0                        15                       0                      0
#  1                        51                       3                      0
#  2                        58                      36                      1
#  3                         0                      90                     10
#  4                         0                       0                      0
#  ..                      ...                     ...                    ...
#  836                      57                       2                      0
#  837                       0                       0                      0
#  838                       0                       9                     91
#  839                      69                       8                      0
#  840                       1                      86                     14
#
#      Fouls Drawn - Shoot Fouls Drawn - Off.
#  0                     4                  8
#  1                    12                  0
#  2                     1                  0
#  3                   140                  7
#  4                    22                 14
#  ..                  ...                ...
#  836                  45                  2
#  837                   2                  0
#  838                  26                  0
#  839                  33                 20
#  840                 271                  3
#
#  [629 rows x 9 columns],
#  '2024per_game':               Player  GS   FG   FGA  ORB  DRB  AST  STL  BLK  TOV   PF
#  0         A.J. Green   0  1.5   3.5  0.2  1.0  0.5  0.2  0.1  0.2  0.9
#  1        A.J. Lawson   0  1.3   2.9  0.3  0.9  0.5  0.2  0.1  0.3  0.5
#  2         AJ Griffin   0  0.9   3.1  0.1  0.8  0.3  0.1  0.1  0.4  0.3
#  3       Aaron Gordon  73  5.5   9.8  2.4  4.1  3.5  0.8  0.6  1.4  1.9
#  4      Aaron Holiday   1  2.4   5.3  0.3  1.3  1.8  0.5  0.1  0.7  1.6
#  ..               ...  ..  ...   ...  ...  ...  ...  ...  ...  ...  ...
#  836      Zach LaVine  23  6.8  15.0  0.3  4.8  3.9  0.8  0.3  2.1  2.3
#  837   Zavier Simpson   0  2.4   7.7  0.6  2.3  3.6  1.0  0.4  1.4  1.6
#  838       Zeke Nnaji   0  1.2   2.6  1.1  1.1  0.6  0.3  0.7  0.5  1.4
#  839  Ziaire Williams  15  2.9   7.4  0.7  2.8  1.5  0.7  0.2  1.3  1.7
#  840  Zion Williamson  70  8.9  15.6  1.7  4.1  5.0  1.1  0.7  2.8  2.3
#
#  [629 rows x 11 columns]}

# %%
dfs_by_season['2024'][dfs_by_season['2024']['Player'] == 'Spencer Dinwiddie']
# Out:
#                  Player Team Pos   G    MP   FTr  USG%  \
# 1288  Spencer Dinwiddie  BRK  PG  48  1474  .321  18.6
# 1289  Spencer Dinwiddie  BRK  PG  48  1474  .321  18.6
# 1290  Spencer Dinwiddie  BRK  PG  48  1474  .321  18.6
# 1291  Spencer Dinwiddie  BRK  PG  48  1474  .321  18.6
# 1292  Spencer Dinwiddie  BRK  PG  48  1474  .321  18.6
# 1293  Spencer Dinwiddie  BRK  PG  48  1474  .321  18.6
# 1294  Spencer Dinwiddie  BRK  PG  48  1474  .321  18.6
# 1295  Spencer Dinwiddie  BRK  PG  48  1474  .321  18.6
# 1296  Spencer Dinwiddie  LAL  PG  28   678  .355  12.2
# 1297  Spencer Dinwiddie  LAL  PG  28   678  .355  12.2
# 1298  Spencer Dinwiddie  LAL  PG  28   678  .355  12.2
# 1299  Spencer Dinwiddie  LAL  PG  28   678  .355  12.2
# 1300  Spencer Dinwiddie  LAL  PG  28   678  .355  12.2
# 1301  Spencer Dinwiddie  LAL  PG  28   678  .355  12.2
# 1302  Spencer Dinwiddie  LAL  PG  28   678  .355  12.2
# 1303  Spencer Dinwiddie  LAL  PG  28   678  .355  12.2
#
#      % of FGA by Distance - 2P % of FGA by Distance - 0-3  \
# 1288                      .443                       .140
# 1289                      .443                       .140
# 1290                      .443                       .140
# 1291                      .443                       .140
# 1292                      .362                       .078
# 1293                      .362                       .078
# 1294                      .362                       .078
# 1295                      .362                       .078
# 1296                      .443                       .140
# 1297                      .443                       .140
# 1298                      .443                       .140
# 1299                      .443                       .140
# 1300                      .362                       .078
# 1301                      .362                       .078
# 1302                      .362                       .078
# 1303                      .362                       .078
#
#      % of FGA by Distance - 3-10  ... Corner 3s - %3PA   FG   FGA  ORB  DRB  \
# 1288                        .222  ...             .212  4.1  10.4  0.5  2.8
# 1289                        .222  ...             .212  4.1  10.4  0.5  2.8
# 1290                        .222  ...             .212  2.0   5.0  0.1  1.5
# 1291                        .222  ...             .212  2.0   5.0  0.1  1.5
# 1292                        .177  ...             .367  4.1  10.4  0.5  2.8
# 1293                        .177  ...             .367  4.1  10.4  0.5  2.8
# 1294                        .177  ...             .367  2.0   5.0  0.1  1.5
# 1295                        .177  ...             .367  2.0   5.0  0.1  1.5
# 1296                        .222  ...             .212  4.1  10.4  0.5  2.8
# 1297                        .222  ...             .212  4.1  10.4  0.5  2.8
# 1298                        .222  ...             .212  2.0   5.0  0.1  1.5
# 1299                        .222  ...             .212  2.0   5.0  0.1  1.5
# 1300                        .177  ...             .367  4.1  10.4  0.5  2.8
# 1301                        .177  ...             .367  4.1  10.4  0.5  2.8
# 1302                        .177  ...             .367  2.0   5.0  0.1  1.5
# 1303                        .177  ...             .367  2.0   5.0  0.1  1.5
#
#       AST  STL  BLK  TOV   PF
# 1288  6.0  0.8  0.2  1.3  1.8
# 1289  6.0  0.8  0.2  1.3  1.8
# 1290  2.4  0.5  0.5  1.0  1.9
# 1291  2.4  0.5  0.5  1.0  1.9
# 1292  6.0  0.8  0.2  1.3  1.8
# 1293  6.0  0.8  0.2  1.3  1.8
# 1294  2.4  0.5  0.5  1.0  1.9
# 1295  2.4  0.5  0.5  1.0  1.9
# 1296  6.0  0.8  0.2  1.3  1.8
# 1297  6.0  0.8  0.2  1.3  1.8
# 1298  2.4  0.5  0.5  1.0  1.9
# 1299  2.4  0.5  0.5  1.0  1.9
# 1300  6.0  0.8  0.2  1.3  1.8
# 1301  6.0  0.8  0.2  1.3  1.8
# 1302  2.4  0.5  0.5  1.0  1.9
# 1303  2.4  0.5  0.5  1.0  1.9
#
# [16 rows x 26 columns]

# %%
# Create a new dictionary to hold the merged dataframes by season
dfs_by_season = {}

for season in separated_dfs_by_season:
    merged_df = pd.merge(separated_dfs_by_season[season][season + 'advanced'], separated_dfs_by_season[season][season + 'shooting'], on=['Player', 'GS'], how='inner')
    merged_df = pd.merge(merged_df, separated_dfs_by_season[season][season + 'per_game'], on=['Player', 'GS'], how='inner')
    merged_df = pd.merge(merged_df, separated_dfs_by_season[season][season + 'play-by-play'], on=['Player', 'GS'], how='inner')
    dfs_by_season[season] = merged_df

# %%
for df in dfs_by_season:
    cols_to_drop = []
    for col in dfs_by_season[df].columns:
        if 'GS' in col or 'Awards' in col or 'Foul' in col or 'Position Estimate' in col or '_x' in col or '_y' in col:
            cols_to_drop.append(col)
    dfs_by_season[df].drop(columns=cols_to_drop, inplace=True)

# %%
# Create an empty list to store each season's dataframe with the season column added
df_list = []

# Loop over each season and its corresponding dataframe in dfs_by_season
for season, df in dfs_by_season.items():
    # Create a copy of the dataframe and add a 'Season' column with the current season
    df_copy = df.copy()
    df_copy['Season'] = season
    # Append the modified dataframe to the list
    df_list.append(df_copy)

# Concatenate all dataframes in the list into a single dataframe and set the index appropriately
combined_df = pd.concat(df_list, ignore_index=True)
combined_df.set_index(['Season', 'Player'], inplace=True)

# %%
combined_df
# Out:
#                        Team Pos   G    MP   FTr  USG%  \
# Season Player
# 2001   A.C. Green       MIA  PF  82  1411  .343  14.4
#        A.J. Guyton      CHI  PG  33   630  .094  16.5
#        Aaron McKie      PHI  SG  76  2394  .272  18.9
#        Aaron Williams   NJN  PF  82  2336  .477  17.8
#        Adam Keefe       GSW  PF  67   836  .396  11.5
# ...                     ...  ..  ..   ...   ...   ...
# 2024   Zach LaVine      CHI  SG  25   872  .274  23.8
#        Zavier Simpson   MEM  PG   7   161  .074  17.5
#        Zeke Nnaji       DEN  PF  58   576  .416  15.4
#        Ziaire Williams  MEM  SF  51  1038  .198  19.7
#        Zion Williamson  NOP  PF  70  2207  .452  29.7
#
#                        % of FGA by Distance - 2P % of FGA by Distance - 0-3  \
# Season Player
# 2001   A.C. Green                           .981                       .278
#        A.J. Guyton                          .641                       .078
#        Aaron McKie                          .762                       .232
#        Aaron Williams                       .997                       .502
#        Adam Keefe                           .981                       .377
# ...                                          ...                        ...
# 2024   Zach LaVine                          .551                       .237
#        Zavier Simpson                       .685                       .167
#        Zeke Nnaji                           .846                       .597
#        Ziaire Williams                      .500                       .220
#        Zion Williamson                      .984                       .547
#
#                        % of FGA by Distance - 3-10  \
# Season Player
# 2001   A.C. Green                             .102
#        A.J. Guyton                            .042
#        Aaron McKie                            .137
#        Aaron Williams                         .262
#        Adam Keefe                             .176
# ...                                            ...
# 2024   Zach LaVine                            .136
#        Zavier Simpson                         .333
#        Zeke Nnaji                             .215
#        Ziaire Williams                        .127
#        Zion Williamson                        .404
#
#                        % of FGA by Distance - 10-16  ...   FG   FGA  ORB  DRB  \
# Season Player                                        ...
# 2001   A.C. Green                              .164  ...  1.8   4.0  1.3  2.5
#        A.J. Guyton                             .094  ...  2.4   5.8  0.3  0.8
#        Aaron McKie                             .183  ...  4.4   9.4  0.4  3.7
#        Aaron Williams                          .131  ...  3.6   7.9  2.6  4.6
#        Adam Keefe                              .170  ...  1.0   2.4  1.3  1.8
# ...                                             ...  ...  ...   ...  ...  ...
# 2024   Zach LaVine                             .053  ...  6.8  15.0  0.3  4.8
#        Zavier Simpson                          .093  ...  2.4   7.7  0.6  2.3
#        Zeke Nnaji                              .027  ...  1.2   2.6  1.1  1.1
#        Ziaire Williams                         .085  ...  2.9   7.4  0.7  2.8
#        Zion Williamson                         .030  ...  8.9  15.6  1.7  4.1
#
#                         AST  STL  BLK  TOV   PF Shoot
# Season Player
# 2001   A.C. Green       0.5  0.4  0.1  0.5  1.5    44
#        A.J. Guyton      1.9  0.3  0.2  0.7  1.1     5
#        Aaron McKie      5.0  1.4  0.1  2.7  2.3    73
#        Aaron Williams   1.1  0.7  1.4  1.6  3.9   131
#        Adam Keefe       0.5  0.4  0.3  0.6  1.5    25
# ...                     ...  ...  ...  ...  ...   ...
# 2024   Zach LaVine      3.9  0.8  0.3  2.1  2.3   NaN
#        Zavier Simpson   3.6  1.0  0.4  1.4  1.6   NaN
#        Zeke Nnaji       0.6  0.3  0.7  0.5  1.4   NaN
#        Ziaire Williams  1.5  0.7  0.2  1.3  1.7   NaN
#        Zion Williamson  5.0  1.1  0.7  2.8  2.3   NaN
#
# [12156 rows x 26 columns]

# %%
combined_df.reset_index()[(combined_df.reset_index()['Player'] == 'Spencer Dinwiddie') & (combined_df.reset_index()['Season'] == '2024')]
# Out:
#       Season             Player Team Pos   G    MP   FTr  USG%  \
# 12079   2024  Spencer Dinwiddie  BRK  PG  48  1474  .321  18.6
# 12080   2024  Spencer Dinwiddie  LAL  PG  28   678  .355  12.2
#
#       % of FGA by Distance - 2P % of FGA by Distance - 0-3  ...   FG   FGA  \
# 12079                      .443                       .140  ...  4.1  10.4
# 12080                      .362                       .078  ...  2.0   5.0
#
#        ORB  DRB  AST  STL  BLK  TOV   PF Shoot
# 12079  0.5  2.8  6.0  0.8  0.2  1.3  1.8   NaN
# 12080  0.1  1.5  2.4  0.5  0.5  1.0  1.9   NaN
#
# [2 rows x 28 columns]

# %%
combined_df.to_csv(r"C:\Users\vaugh\Desktop\basketball-pf-research\Basketball-reference data\df_with_all_positions_and_teams(2001-2024).csv")

# %%
# Filter for only PFs
combined_df = combined_df[combined_df['Pos'] == 'PF']
combined_df.drop(columns = ['Pos'], inplace=True)
# Out:
# C:\Users\vaugh\AppData\Local\Temp\ipykernel_54328\696733241.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   combined_df.drop(columns = ['Pos'], inplace=True)

# %%
combined_df = combined_df.apply(pd.to_numeric, errors='coerce')

# Changing all the values in the df to be floats
combined_df = combined_df.astype(float)

combined_df.fillna(0, inplace=True)  # Filling NaNs with 0

# Replacing any infinite values with 0
combined_df.replace([np.inf, -np.inf], 0, inplace=True)

per_48_stats = ['FGA', 'PF', 'BLK', 'STL', 'DRB', 'ORB', 'TOV', 'AST']

for stat in per_48_stats:
    combined_df[stat] = combined_df[stat] / (combined_df['MP'] / combined_df['G']) * 48

# %%
# Cleaning up the dataframe
combined_df.rename(columns = {'PF': 'Personal Fouls Committed'}, inplace=True)
combined_df.rename(columns = {'Fouls Drawn - Shoot': 'Shooting Fouls Drawn'}, inplace=True)
combined_df.drop(columns = ['% of FGA by Distance - 2P', 'FG'], inplace=True)

# %%
combined_df
# Out:
#                               G      MP    FTr  USG%  \
# Season Player
# 2001   A.C. Green          82.0  1411.0  0.343  14.4
#        Aaron Williams      82.0  2336.0  0.477  17.8
#        Adam Keefe          67.0   836.0  0.396  11.5
#        Al Harrington       78.0  1892.0  0.289  18.8
#        Alan Henderson      73.0  1810.0  0.404  22.6
# ...                         ...     ...    ...   ...
# 2024   Usman Garuba         6.0    18.0  0.333  20.8
#        Wenyen Gabriel       5.0    81.0  0.227  17.0
#        Xavier Tillman Sr.  54.0   974.0  0.179  14.8
#        Zeke Nnaji          58.0   576.0  0.416  15.4
#        Zion Williamson     70.0  2207.0  0.452  29.7
#
#                            % of FGA by Distance - 0-3  \
# Season Player
# 2001   A.C. Green                               0.278
#        Aaron Williams                           0.502
#        Adam Keefe                               0.377
#        Al Harrington                            0.333
#        Alan Henderson                           0.434
# ...                                               ...
# 2024   Usman Garuba                             0.333
#        Wenyen Gabriel                           0.545
#        Xavier Tillman Sr.                       0.337
#        Zeke Nnaji                               0.597
#        Zion Williamson                          0.547
#
#                            % of FGA by Distance - 3-10  \
# Season Player
# 2001   A.C. Green                                0.102
#        Aaron Williams                            0.262
#        Adam Keefe                                0.176
#        Al Harrington                             0.250
#        Alan Henderson                            0.304
# ...                                                ...
# 2024   Usman Garuba                              0.500
#        Wenyen Gabriel                            0.091
#        Xavier Tillman Sr.                        0.294
#        Zeke Nnaji                                0.215
#        Zion Williamson                           0.404
#
#                            % of FGA by Distance - 10-16  \
# Season Player
# 2001   A.C. Green                                 0.164
#        Aaron Williams                             0.131
#        Adam Keefe                                 0.170
#        Al Harrington                              0.193
#        Alan Henderson                             0.210
# ...                                                 ...
# 2024   Usman Garuba                               0.000
#        Wenyen Gabriel                             0.091
#        Xavier Tillman Sr.                         0.061
#        Zeke Nnaji                                 0.027
#        Zion Williamson                            0.030
#
#                            % of FGA by Distance - 16-3P  \
# Season Player
# 2001   A.C. Green                                 0.438
#        Aaron Williams                             0.103
#        Adam Keefe                                 0.258
#        Al Harrington                              0.210
#        Alan Henderson                             0.051
# ...                                                 ...
# 2024   Usman Garuba                               0.000
#        Wenyen Gabriel                             0.000
#        Xavier Tillman Sr.                         0.018
#        Zeke Nnaji                                 0.007
#        Zion Williamson                            0.003
#
#                            % of FGA by Distance - 3P  % of FG Ast'd - 2P  ...  \
# Season Player                                                             ...
# 2001   A.C. Green                              0.019               0.764  ...
#        Aaron Williams                          0.003               0.623  ...
#        Adam Keefe                              0.019               0.683  ...
#        Al Harrington                           0.013               0.675  ...
#        Alan Henderson                          0.001               0.537  ...
# ...                                              ...                 ...  ...
# 2024   Usman Garuba                            0.167               0.000  ...
#        Wenyen Gabriel                          0.273               0.714  ...
#        Xavier Tillman Sr.                      0.290               0.812  ...
#        Zeke Nnaji                              0.154               0.619  ...
#        Zion Williamson                         0.016               0.474  ...
#
#                                  STL         BLK        TOV  \
# Season Player
# 2001   A.C. Green           3.112549    0.778137   3.890686
#        Aaron Williams       1.987296    3.974592   4.542391
#        Adam Keefe           5.919425    4.439569   8.879137
#        Al Harrington        3.132704    0.783176   7.440173
#        Alan Henderson       2.623428    1.499101   6.371181
# ...                              ...         ...        ...
# 2024   Usman Garuba        51.200000  128.000000  76.800000
#        Wenyen Gabriel       3.511660    3.511660  14.046639
#        Xavier Tillman Sr.   6.373744    5.665550   4.249162
#        Zeke Nnaji           7.008333   16.352778  11.680556
#        Zion Williamson      2.549568    1.622452   6.489809
#
#                            Personal Fouls Committed  Position Estimate - PG%  \
# Season Player
# 2001   A.C. Green                         11.672057                      0.0
#        Aaron Williams                     11.072077                      0.0
#        Adam Keefe                         22.197843                      0.0
#        Al Harrington                      11.356053                      0.0
#        Alan Henderson                      8.245058                      0.0
# ...                                             ...                      ...
# 2024   Usman Garuba                       76.800000                      0.0
#        Wenyen Gabriel                     17.558299                      0.0
#        Xavier Tillman Sr.                  9.914712                      0.0
#        Zeke Nnaji                         32.705556                      0.0
#        Zion Williamson                     5.330915                      0.0
#
#                            Position Estimate - SG%  Position Estimate - SF%  \
# Season Player
# 2001   A.C. Green                              0.0                      0.0
#        Aaron Williams                          0.0                      6.0
#        Adam Keefe                              0.0                     17.0
#        Al Harrington                           1.0                     70.0
#        Alan Henderson                          0.0                      0.0
# ...                                            ...                      ...
# 2024   Usman Garuba                            0.0                      0.0
#        Wenyen Gabriel                          8.0                     75.0
#        Xavier Tillman Sr.                      0.0                      0.0
#        Zeke Nnaji                              0.0                      0.0
#        Zion Williamson                         0.0                      1.0
#
#                            Position Estimate - PF%  Position Estimate - C%  \
# Season Player
# 2001   A.C. Green                             47.0                    53.0
#        Aaron Williams                         68.0                    26.0
#        Adam Keefe                             70.0                    13.0
#        Al Harrington                          28.0                     1.0
#        Alan Henderson                         79.0                    21.0
# ...                                            ...                     ...
# 2024   Usman Garuba                           10.0                    90.0
#        Wenyen Gabriel                         16.0                     0.0
#        Xavier Tillman Sr.                     43.0                    57.0
#        Zeke Nnaji                              9.0                    91.0
#        Zion Williamson                        86.0                    14.0
#
#                            Shoot
# Season Player
# 2001   A.C. Green           44.0
#        Aaron Williams      131.0
#        Adam Keefe           25.0
#        Al Harrington        65.0
#        Alan Henderson      124.0
# ...                          ...
# 2024   Usman Garuba          0.0
#        Wenyen Gabriel        0.0
#        Xavier Tillman Sr.    0.0
#        Zeke Nnaji            0.0
#        Zion Williamson       0.0
#
# [2365 rows x 27 columns]

# %%
# Create a copy of the dataframe to apply PCA on
final_df = combined_df

# Changing all the values in the df to be floats so that I can apply PCA
final_df.fillna(0, inplace=True)  # Filling NaNs with 0
final_df = final_df.astype(float)

# Replacing any infinite values with 0
final_df.replace([np.inf, -np.inf], 0, inplace=True)

ordered_cols = ['G', 'MP', 'USG%', 'FGA', 'Personal Fouls Committed', 'BLK', 'STL', 'DRB', 'ORB', 'TOV', 'AST', "% of FG Ast'd - 3P", "% of FG Ast'd - 2P", 'FTr', 'Shooting Fouls Drawn', 'Corner 3s - %3PA', '% of FGA by Distance - 3P', '% of FGA by Distance - 16-3P', '% of FGA by Distance - 10-16', '% of FGA by Distance - 3-10', '% of FGA by Distance - 0-3', 'Dunks - %FGA', ]
final_df = final_df.reindex(columns = ordered_cols)

# Removing any players named "Player"
final_df.reset_index(inplace=True)
final_df = final_df[final_df['Player'] != 'Player']
final_df.set_index(['Season', 'Player'], inplace=True)

# %%
final_df
# Out:
#                               G      MP  USG%         FGA  \
# Season Player
# 2001   A.C. Green          82.0  1411.0  14.4   31.125486
#        Aaron Williams      82.0  2336.0  17.8   22.428054
#        Adam Keefe          67.0   836.0  11.5   35.516550
#        Al Harrington       78.0  1892.0  18.8   27.411163
#        Alan Henderson      73.0  1810.0  22.6   34.479334
# ...                         ...     ...   ...         ...
# 2024   Usman Garuba         6.0    18.0  20.8  256.000000
#        Wenyen Gabriel       5.0    81.0  17.0   38.628258
#        Xavier Tillman Sr.  54.0   974.0  14.8   36.826074
#        Zeke Nnaji          58.0   576.0  15.4   60.738889
#        Zion Williamson     70.0  2207.0  29.7   36.157508
#
#                            Personal Fouls Committed         BLK        STL  \
# Season Player
# 2001   A.C. Green                         11.672057    0.778137   3.112549
#        Aaron Williams                     11.072077    3.974592   1.987296
#        Adam Keefe                         22.197843    4.439569   5.919425
#        Al Harrington                      11.356053    0.783176   3.132704
#        Alan Henderson                      8.245058    1.499101   2.623428
# ...                                             ...         ...        ...
# 2024   Usman Garuba                       76.800000  128.000000  51.200000
#        Wenyen Gabriel                     17.558299    3.511660   3.511660
#        Xavier Tillman Sr.                  9.914712    5.665550   6.373744
#        Zeke Nnaji                         32.705556   16.352778   7.008333
#        Zion Williamson                     5.330915    1.622452   2.549568
#
#                                   DRB         ORB        TOV  ...  \
# Season Player                                                 ...
# 2001   A.C. Green           19.453429   10.115783   3.890686  ...
#        Aaron Williams       13.059373    7.381385   4.542391  ...
#        Adam Keefe           26.637412   19.238131   8.879137  ...
#        Al Harrington        13.313993    5.873821   7.440173  ...
#        Alan Henderson       11.618037    9.369384   6.371181  ...
# ...                               ...         ...        ...  ...
# 2024   Usman Garuba        179.200000  128.000000  76.800000  ...
#        Wenyen Gabriel       31.604938   12.290809  14.046639  ...
#        Xavier Tillman Sr.   18.413037    9.206519   4.249162  ...
#        Zeke Nnaji           25.697222   25.697222  11.680556  ...
#        Zion Williamson       9.502935    3.940241   6.489809  ...
#
#                            % of FG Ast'd - 2P    FTr  Shooting Fouls Drawn  \
# Season Player
# 2001   A.C. Green                       0.764  0.343                   NaN
#        Aaron Williams                   0.623  0.477                   NaN
#        Adam Keefe                       0.683  0.396                   NaN
#        Al Harrington                    0.675  0.289                   NaN
#        Alan Henderson                   0.537  0.404                   NaN
# ...                                       ...    ...                   ...
# 2024   Usman Garuba                     0.000  0.333                   NaN
#        Wenyen Gabriel                   0.714  0.227                   NaN
#        Xavier Tillman Sr.               0.812  0.179                   NaN
#        Zeke Nnaji                       0.619  0.416                   NaN
#        Zion Williamson                  0.474  0.452                   NaN
#
#                            Corner 3s - %3PA  % of FGA by Distance - 3P  \
# Season Player
# 2001   A.C. Green                     0.167                      0.019
#        Aaron Williams                 0.000                      0.003
#        Adam Keefe                     0.333                      0.019
#        Al Harrington                  0.143                      0.013
#        Alan Henderson                 0.000                      0.001
# ...                                     ...                        ...
# 2024   Usman Garuba                   0.000                      0.167
#        Wenyen Gabriel                 0.500                      0.273
#        Xavier Tillman Sr.             0.617                      0.290
#        Zeke Nnaji                     0.391                      0.154
#        Zion Williamson                0.111                      0.016
#
#                            % of FGA by Distance - 16-3P  \
# Season Player
# 2001   A.C. Green                                 0.438
#        Aaron Williams                             0.103
#        Adam Keefe                                 0.258
#        Al Harrington                              0.210
#        Alan Henderson                             0.051
# ...                                                 ...
# 2024   Usman Garuba                               0.000
#        Wenyen Gabriel                             0.000
#        Xavier Tillman Sr.                         0.018
#        Zeke Nnaji                                 0.007
#        Zion Williamson                            0.003
#
#                            % of FGA by Distance - 10-16  \
# Season Player
# 2001   A.C. Green                                 0.164
#        Aaron Williams                             0.131
#        Adam Keefe                                 0.170
#        Al Harrington                              0.193
#        Alan Henderson                             0.210
# ...                                                 ...
# 2024   Usman Garuba                               0.000
#        Wenyen Gabriel                             0.091
#        Xavier Tillman Sr.                         0.061
#        Zeke Nnaji                                 0.027
#        Zion Williamson                            0.030
#
#                            % of FGA by Distance - 3-10  \
# Season Player
# 2001   A.C. Green                                0.102
#        Aaron Williams                            0.262
#        Adam Keefe                                0.176
#        Al Harrington                             0.250
#        Alan Henderson                            0.304
# ...                                                ...
# 2024   Usman Garuba                              0.500
#        Wenyen Gabriel                            0.091
#        Xavier Tillman Sr.                        0.294
#        Zeke Nnaji                                0.215
#        Zion Williamson                           0.404
#
#                            % of FGA by Distance - 0-3  Dunks - %FGA
# Season Player
# 2001   A.C. Green                               0.278         0.012
#        Aaron Williams                           0.502         0.129
#        Adam Keefe                               0.377         0.038
#        Al Harrington                            0.333         0.068
#        Alan Henderson                           0.434         0.046
# ...                                               ...           ...
# 2024   Usman Garuba                             0.333         0.000
#        Wenyen Gabriel                           0.545         0.136
#        Xavier Tillman Sr.                       0.337         0.065
#        Zeke Nnaji                               0.597         0.181
#        Zion Williamson                          0.547         0.080
#
# [2365 rows x 22 columns]
